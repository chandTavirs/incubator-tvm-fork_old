# %%
# %matplotlib inline
import mpld3
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot
import seaborn as sns

df1 = pd.read_csv("ten_resnets_ref_clk.csv")

# %%
df1['ro_data']
# Out:
# 0           1800
# 1         242060
# 2         418160
# 3         573160
# 4         738500
#           ...
# 85913     558360
# 85914     708820
# 85915     860164
# 85916    1010140
# 85917    1159924
# Name: ro_data, Length: 85918, dtype: int64

# %%
# mpld3.enable_notebook()

# %%
df1.plot(subplots=True, figsize=(20,5))
# Out:
# array([<AxesSubplot:>], dtype=object)

# %%
autocorrelation_plot(df1)
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
sns.lineplot(df1)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decompose = seasonal_decompose(df1,model='additive', period=1000)
decompose.plot()

# %%
rolling_mean = df1.rolling(1000).mean()
rolling_std = df1.rolling(1000).std()

plt.plot(df1, color="blue",label="Original RO Data")
plt.plot(rolling_mean, color="red", label="Rolling Mean RO")
plt.plot(rolling_std, color="black", label = "Rolling Standard Deviation RO")
plt.title("RO Time series, Rolling Mean, Standard Deviation")
plt.legend(loc="best")
