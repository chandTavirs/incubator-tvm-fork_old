# %%
# %matplotlib inline

# %% [markdown]
# # Auto-tuning a ALU fused op on VTA

# %%
import os
#from mxnet.gluon.model_zoo import vision
import numpy as np
from PIL import Image

from tvm import topi
import tvm
from tvm import te
from tvm import rpc, autotvm, relay
from tvm.contrib import download
from tvm.autotvm.measure.measure_methods import request_remote
from tvm.autotvm.tuner import XGBTuner, GATuner, RandomTuner, GridSearchTuner
from tvm.autotvm import record

import vta
from vta.testing import simulator
from vta.top import graph_pack
import copy
import torch

# %%
from torch import nn
from torch.nn import functional as F

class Residual(nn.Module):  #@save
    """The Residual block of ResNet."""
    def __init__(self, input_channels, num_channels, strides=1):
        super().__init__()
        
        self.conv1 = nn.Conv2d(input_channels, num_channels,
                               kernel_size=3, padding=1, stride=strides)
        self.conv2 = nn.Conv2d(num_channels, num_channels,
                               kernel_size=3, padding=1, stride=strides)
        
        self.max_pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.relu = nn.ReLU()
        self.bn1 = nn.BatchNorm2d(num_channels)
        self.bn2 = nn.BatchNorm2d(num_channels)


    def forward(self, X):
        
        #Y = self.bn1(self.relu(self.conv1(X)))
        Y = self.conv1(X)
        Y = self.max_pool(Y)
#         Y = self.bn2(self.relu(self.conv2(Y)))
#         Y = self.max_pool(Y)
    
        
#         return self.relu(Y)
        return Y

b1 = nn.Sequential(nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3),
                   nn.BatchNorm2d(64), nn.ReLU(inplace=True),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))

def resnet_block(input_channels, num_channels, num_residuals):
    blk = []
    for i in range(num_residuals):
        blk.append(Residual(num_channels, num_channels))
    return blk

b2 = nn.Sequential(*resnet_block(64, 64, 1))

net = nn.Sequential(b1,b2,nn.AdaptiveAvgPool2d((1,1)))

# %% [markdown]
# # Compile network
# Perform vta-specific compilation with Relay from a Gluon model

# %%
def compile_network(env, target, model, start_pack, stop_pack):

    # Populate the shape and data type dictionary
    dtype_dict = {"data": "float32"}
    shape_dict = {"data": (env.BATCH, 3, 224, 224)}

    # Get off the shelf gluon model, and convert to relay
    gluon_model = vision.get_model(model, pretrained=True)
    mod, params = relay.frontend.from_mxnet(gluon_model, shape_dict)

    # Update shape and type dictionary
    shape_dict.update({k: v.shape for k, v in params.items()})
    dtype_dict.update({k: str(v.dtype) for k, v in params.items()})

    # Perform quantization in Relay
    # Note: We set opt_level to 3 in order to fold batch norm
    with relay.build_config(opt_level=3):
        with relay.quantize.qconfig(global_scale=8.0, skip_conv_layers=[0]):
            mod = relay.quantize.quantize(mod, params=params)

    # Perform graph packing and constant folding for VTA target
    if target.device_name == "vta":
        assert env.BLOCK_IN == env.BLOCK_OUT
        relay_prog = graph_pack(
            mod["main"],
            env.BATCH,
            env.BLOCK_OUT,
            env.WGT_WIDTH,
            start_name=start_pack,
            stop_name=stop_pack,
        )

    return relay_prog, params

# %%
def compile_network_torch(env, target, model, start_pack, stop_pack):

    input_name = "input0"

    # Populate the shape and data type dictionary for ImageNet classifier input
    dtype_dict = {input_name: "float32"}
    shape_dict = {input_name: (env.BATCH, 3, 224, 224)}

    
    input_shape = [1, 3, 224, 224]
    input_data = torch.randn(input_shape)
    scripted_model = torch.jit.trace(model, input_data).eval()
    
    shape_list = [(input_name, input_shape)]


    # Start front end compilation
    mod, params = relay.frontend.from_pytorch(scripted_model, shape_list)

    # Update shape and type dictionary
    shape_dict.update({k: v.shape for k, v in params.items()})
    dtype_dict.update({k: str(v.dtype) for k, v in params.items()})

    # Perform quantization in Relay
    # Note: We set opt_level to 3 in order to fold batch norm
    with relay.build_config(opt_level=3):
        with relay.quantize.qconfig(global_scale=8.0, skip_conv_layers=[0]):
            mod = relay.quantize.quantize(mod, params=params)

    # Perform graph packing and constant folding for VTA target
    if target.device_name == "vta":
        assert env.BLOCK_IN == env.BLOCK_OUT
        relay_prog = graph_pack(
            mod["main"],
            env.BATCH,
            env.BLOCK_IN,
            env.BLOCK_OUT,
            env.WGT_WIDTH,
            start_name='cast',
            start_name_idx=11,
            stop_name='cast',
            stop_name_idx=19,
        )

    return relay_prog, params

# %% [markdown]
# # Set Tuning Options
# Before tuning, we should apply some configurations.
# Here we use an Pynq-Z1 board as an example.

# %%
# Tracker host and port can be set by your environment
tracker_host = os.environ.get("TVM_TRACKER_HOST", "0.0.0.0")
tracker_port = int(os.environ.get("TVM_TRACKER_PORT", 9190))

# Load VTA parameters from the vta/config/vta_config.json file
env = vta.get_env()

# This target is used for cross compilation. You can query it by :code:`gcc -v` on your device.
# Set ``device=arm_cpu`` to run inference on the CPU
# or ``device=vta`` to run inference on the FPGA.
device = "vta"
target = env.target if device == "vta" else env.target_vta_cpu

# Name of Gluon model to compile
# The ``start_pack`` and ``stop_pack`` labels indicate where
# to start and end the graph packing relay pass: in other words
# where to start and finish offloading to VTA.
network = net
start_pack = "nn.max_pool2d"
stop_pack = "nn.adaptive_avg_pool2d"

# Tuning option
log_file = "%s.maxpool.%s.log" % (device, "resnet")
tuning_option = {
    "log_filename": log_file,
    "tuner": "random",
    "n_trial": 1000,
    "early_stopping": None,
    "measure_option": autotvm.measure_option(
        builder=autotvm.LocalBuilder(n_parallel=1),
        runner=autotvm.RPCRunner(
            env.TARGET,
            host=tracker_host,
            port=tracker_port,
            number=5,
            timeout=60,
            # check_correctness=True, # TODO: re-enable when check_correctness works again.
        ),
    ),
}


def log_to_file(file_out, protocol="json"):
    """Log the tuning records into file.
    The rows of the log are stored in the format of autotvm.record.encode.
    for lhs == rhs, we add an extra rhs = [] record

    Parameters
    ----------
    file_out : str
        The file to log to.
    protocol: str, optional
        The log protocol. Can be 'json' or 'pickle'

    Returns
    -------
    callback : callable
        Callback function to do the logging.
    """

    def _callback(_, inputs, results):
        with open(file_out, "a") as f:
            for inp, result in zip(inputs, results):
                f.write(record.encode(inp, result, protocol) + "\n")

                # we only consider task with same lhs and rhs
                if inp.task.args[0] == inp.task.args[1]:
                    args = list(inp.task.args)
                    args[1] = (args[0][0], (), args[0][2])
                    inp_copy = copy.deepcopy(inp)
                    inp_copy.task.args = tuple(args)
                    f.write(record.encode(inp_copy, result, protocol) + "\n")

    return _callback


def tune_tasks(
    tasks,
    measure_option,
    tuner="xgb",
    n_trial=10,
    early_stopping=None,
    log_filename="tuning.log",
    use_transfer_learning=True,
):

    # create tmp log file
    tmp_log_file = log_filename + ".tmp"
    if os.path.exists(tmp_log_file):
        os.remove(tmp_log_file)

    for i, tsk in enumerate(reversed(tasks)):
        prefix = "[Task %2d/%2d] " % (i + 1, len(tasks))

        # create tuner
        if tuner == "xgb" or tuner == "xgb-rank":
            tuner_obj = XGBTuner(tsk, loss_type="rank")
        elif tuner == "xgb_knob":
            tuner_obj = XGBTuner(tsk, loss_type="rank", feature_type="knob")
        elif tuner == "ga":
            tuner_obj = GATuner(tsk, pop_size=50)
        elif tuner == "random":
            tuner_obj = RandomTuner(tsk)
        elif tuner == "gridsearch":
            tuner_obj = GridSearchTuner(tsk)
        else:
            raise ValueError("Invalid tuner: " + tuner)

        if use_transfer_learning:
            if os.path.isfile(tmp_log_file):
                tuner_obj.load_history(autotvm.record.load_from_file(tmp_log_file))

        # do tuning
        tsk_trial = min(n_trial, len(tsk.config_space))
        tuner_obj.tune(
            n_trial=tsk_trial,
            early_stopping=early_stopping,
            measure_option=measure_option,
            callbacks=[
                autotvm.callback.progress_bar(tsk_trial, prefix=prefix),
                log_to_file(tmp_log_file),
            ],
        )

    # pick best records to a cache file
    autotvm.record.pick_best(tmp_log_file, log_filename)
    os.remove(tmp_log_file)

# %% [markdown]
# Register VTA-specific tuning tasks

# %%
def register_vta_tuning_tasks():
    from tvm.autotvm.task import TaskExtractEnv

    @tvm.te.tag_scope(tag=topi.tag.ELEMWISE)
    def my_clip(x, a_min, a_max):
        """Unlike topi's current clip, put min and max into two stages."""
        const_min = tvm.tir.const(a_min, x.dtype)
        const_max = tvm.tir.const(a_max, x.dtype)
        x = te.compute(x.shape, lambda *i: tvm.te.min(x(*i), const_max), name="clipA")
        x = te.compute(x.shape, lambda *i: tvm.te.max(x(*i), const_min), name="clipB")
        return x

    # init autotvm env to register VTA operator
    TaskExtractEnv()

    @autotvm.template("add.vta")
    def _topi_add(*args, **kwargs):
        assert not kwargs, "Do not support kwargs in template function call"
        A, B = args[:2]

        with tvm.target.vta():
            res = vta.top.op.add_packed(*args, **kwargs)
            res = my_clip(res, 0, 127)
            res = topi.cast(res, "int8")

        if tvm.target.Target.current().device_name == "vta":
            s = vta.top.op.schedule_add_packed([res])
        else:
            s = te.create_schedule([res.op])
        return s, [A, B, res]

    @autotvm.template("multiply.vta")
    def _topi_multiply(*args, **kwargs):
        assert not kwargs, "Do not support kwargs in template function call"
        A, B = args[:2]

        with tvm.target.vta():
            res = vta.top.op.multiply_packed(*args, **kwargs)
            res = my_clip(res, 0, 127)
            res = topi.cast(res, "int8")

        if tvm.target.Target.current().device_name == "vta":
            s = vta.top.op.schedule_multiply_packed([res])
        else:
            s = te.create_schedule([res.op])
        return s, [A, B, res]
    
    @autotvm.template("pooling_packed.vta")
    def _topi_max_pool2d(*args, **kwargs):
        assert not kwargs, "Do not support kwargs in template function call"
        A = args[:1]
        with tvm.target.vta():
            res = vta.top.pooling_packed(*args, **kwargs)
            res = topi.cast(res, "int8")
            
        if tvm.target.Target.current().device_name == "vta":
            s = vta.top.schedule_pooling_packed([res])
        else:
            s = te.create_schedule([res.op])
        return s, [A, res]

# %% [markdown]
# Finally, we launch tuning jobs and evaluate the end-to-end performance.

# %%
def tune_and_evaluate(tuning_opt):

#     if env.TARGET != "intelfocl":
#         print("ALU only op only available for intelfocl target")
#         return

    # Register VTA tuning tasks
    #register_vta_tuning_tasks()

    # Perform task extraction on Relay program
    print("Extract tasks...")
    relay_prog, params = compile_network_torch(env, target, network, start_pack, stop_pack)
    mod = tvm.IRModule.from_expr(relay_prog)
    tasks = autotvm.task.extract_from_program(
        mod,
        params=params,
        ops=(
            relay.op.get("nn.max_pool2d"),
        ),
        target=tvm.target.Target(target),
    )
    #print(tasks)
    #print(platak)

    # filter out non-packed alu task
    tasks = list(filter(lambda t: len(t.args[0][1]) > 4, tasks))
    # filter out float alu task
    tasks = list(filter(lambda t: t.args[0][2] != "float32", tasks))

    # We should have extracted 10 convolution tasks
    tasks_set = {}
    print("Extracted {} alu tasks:".format(len(tasks)))
    for tsk in tasks:
        print("tsk = ", tsk)

#         if len(tsk.args[1][1]) == 0:
#             args = list(tsk.args)
#             args[1] = args[0]
#             tsk.args = tuple(args)

        if (tsk.name, tsk.args) in tasks_set:
            print("task {} already exists".format(tsk))
        tasks_set[(tsk.name, tsk.args)] = tsk

    tasks = list(tasks_set.values())
    print("After merged, final #tasks={}, tasks = {}".format(len(tasks), tasks))

    # run tuning tasks
    print("Tuning...")
    tune_tasks(tasks, **tuning_opt)


# Run the tuning and evaluate the results
tune_and_evaluate(tuning_option)
# Out:
# Extract tasks...
# Splitting into row to reduce scratchpad utilization
# Acc utilization: 2240 elems
# Acc size: 32768 elems
# Splitting into row to reduce scratchpad utilization
# Acc utilization: 2240 elems
# Acc size: 32768 elems
# Extracted 1 alu tasks:
# tsk =  Task(func_name=pooling_packed.vta, args=(('TENSOR', (1, 4, 56, 56, 1, 16), 'int32'), (2, 2), (2, 2), (0, 0, 0, 0), 'max', 0, 'NCHW1n16c', True), kwargs={}, workload=('pooling_packed.vta', ('TENSOR', (1, 4, 56, 56, 1, 16), 'int32'), (2, 2), (2, 2), (0, 0, 0, 0), 'max', 0, 'NCHW1n16c', True))
# After merged, final #tasks=1, tasks = [Task(func_name=pooling_packed.vta, args=(('TENSOR', (1, 4, 56, 56, 1, 16), 'int32'), (2, 2), (2, 2), (0, 0, 0, 0), 'max', 0, 'NCHW1n16c', True), kwargs={}, workload=('pooling_packed.vta', ('TENSOR', (1, 4, 56, 56, 1, 16), 'int32'), (2, 2), (2, 2), (0, 0, 0, 0), 'max', 0, 'NCHW1n16c', True))]
# Tuning...
# [Task  1/ 1]  Current/Best:    0.00/   0.00 GFLOPS | Progress: (0/1) | 0.00 sSplitting into row to reduce scratchpad utilization
# Acc utilization: 2240 elems
# Acc size: 32768 elems
# [Task  1/ 1]  Current/Best:    0.00/   0.00 GFLOPS | Progress: (1/1) | 10.13 s
# WARNING:root:Could not find any valid schedule for task Task(func_name=pooling_packed.vta, args=(('TENSOR', (1, 4, 56, 56, 1, 16), 'int32'), (2, 2), (2, 2), (0, 0, 0, 0), 'max', 0, 'NCHW1n16c', True), kwargs={}, workload=('pooling_packed.vta', ('TENSOR', (1, 4, 56, 56, 1, 16), 'int32'), (2, 2), (2, 2), (0, 0, 0, 0), 'max', 0, 'NCHW1n16c', True)). A file containing the errors has been written to /tmp/tvm_tuning_errors_4s59gkur.log.
#  Done.

# %%
relay_prog, params = compile_network(env, target, network, start_pack, stop_pack)
mod = tvm.IRModule.from_expr(relay_prog)

# %%
print(mod.astext(show_meta_data=False))
# Out:
# #[version = "0.0.5"]
# def @main /* id=94900424908496 */(%data: Tensor[(1, 3, 224, 224), float32]) -> Tensor[(1, 1000), float32] {
#   %0 = add(%data, meta[relay.Constant][0] /* ty=Tensor[(3, 1, 1), float32] */) /* ty=Tensor[(1, 3, 224, 224), float32] */;
#   %1 = nn.conv2d(%0, meta[relay.Constant][1] /* ty=Tensor[(64, 3, 7, 7), float32] */, strides=[2, 2], padding=[3, 3, 3, 3], channels=64, kernel_size=[7, 7]) /* ty=Tensor[(1, 64, 112, 112), float32] */;
#   %2 = add(%1, meta[relay.Constant][2] /* ty=Tensor[(64, 1, 1), float32] */) /* ty=Tensor[(1, 64, 112, 112), float32] */;
#   %3 = nn.relu(%2) /* ty=Tensor[(1, 64, 112, 112), float32] */;
#   %4 = nn.max_pool2d(%3, pool_size=[3, 3], strides=[2, 2], padding=[1, 1, 1, 1]) /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %5 = reshape(%4, newshape=[1, 1, 4, 16, 56, 56]) /* ty=Tensor[(1, 1, 4, 16, 56, 56), float32] */;
#   %6 = transpose(%5, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(1, 4, 56, 56, 1, 16), float32] */;
#   %7 = reshape(meta[relay.Constant][3] /* ty=Tensor[(64, 1, 1), float32] */, newshape=[4, 16, 1, 1, 1]) /* ty=Tensor[(4, 16, 1, 1, 1), float32] */;
#   %8 = transpose(%7, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(4, 1, 1, 1, 16), float32] */;
#   %9 = annotation.stop_fusion(%6) /* ty=Tensor[(1, 4, 56, 56, 1, 16), float32] */;
#   %10 = broadcast_to(%8, shape=[4, 1, 1, 1, 16], dtype="") /* ty=Tensor[(4, 1, 1, 1, 16), float32] */;
#   %11 = reshape(meta[relay.Constant][4] /* ty=Tensor[(64, 1, 1), float32] */, newshape=[4, 16, 1, 1, 1]) /* ty=Tensor[(4, 16, 1, 1, 1), float32] */;
#   %12 = transpose(%11, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(4, 1, 1, 1, 16), float32] */;
#   %13 = multiply(%9, %10) /* ty=Tensor[(1, 4, 56, 56, 1, 16), float32] */;
#   %14 = broadcast_to(%12, shape=[4, 1, 1, 1, 16], dtype="") /* ty=Tensor[(4, 1, 1, 1, 16), float32] */;
#   %15 = add(%13, %14) /* ty=Tensor[(1, 4, 56, 56, 1, 16), float32] */;
#   %16 = nn.relu(%15) /* ty=Tensor[(1, 4, 56, 56, 1, 16), float32] */;
#   %17 = annotation.stop_fusion(%16) /* ty=Tensor[(1, 4, 56, 56, 1, 16), float32] */;
#   %18 = multiply(%17, 16f /* ty=float32 */) /* ty=Tensor[(1, 4, 56, 56, 1, 16), float32] */;
#   %19 = round(%18) /* ty=Tensor[(1, 4, 56, 56, 1, 16), float32] */;
#   %20 = clip(%19, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 4, 56, 56, 1, 16), float32] */;
#   %21 = reshape(meta[relay.Constant][5] /* ty=Tensor[(64, 64, 1, 1), int8] */, newshape=[4, 16, 4, 16, 1, 1]) /* ty=Tensor[(4, 16, 4, 16, 1, 1), int8] */;
#   %22 = cast(%20, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %23 = transpose(%21, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(4, 4, 1, 1, 16, 16), int8] */;
#   %24 = reshape(meta[relay.Constant][6] /* ty=Tensor[(64, 1, 1), int32] */, newshape=[4, 16, 1, 1, 1]) /* ty=Tensor[(4, 16, 1, 1, 1), int32] */;
#   %25 = transpose(%24, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %26 = nn.conv2d(%22, %23, padding=[0, 0, 0, 0], channels=64, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %27 = broadcast_to(%25, shape=[4, 1, 1, 1, 16], dtype="") /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %28 = add(%26, %27) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %29 = nn.relu(%28) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %30 = add(%29, 32 /* ty=int32 */) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %31 = right_shift(%30, 6 /* ty=int32 */) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %32 = clip(%31, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %33 = cast(%32, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %34 = reshape(meta[relay.Constant][7] /* ty=Tensor[(64, 64, 3, 3), int8] */, newshape=[4, 16, 4, 16, 3, 3]) /* ty=Tensor[(4, 16, 4, 16, 3, 3), int8] */;
#   %35 = annotation.stop_fusion(%33) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %36 = transpose(%34, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(4, 4, 3, 3, 16, 16), int8] */;
#   %37 = reshape(meta[relay.Constant][8] /* ty=Tensor[(64, 1, 1), int32] */, newshape=[4, 16, 1, 1, 1]) /* ty=Tensor[(4, 16, 1, 1, 1), int32] */;
#   %38 = transpose(%37, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %39 = nn.conv2d(%35, %36, padding=[1, 1, 1, 1], channels=64, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %40 = broadcast_to(%38, shape=[4, 1, 1, 1, 16], dtype="") /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %41 = add(%39, %40) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %42 = nn.relu(%41) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %43 = add(%42, 64 /* ty=int32 */) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %44 = right_shift(%43, 7 /* ty=int32 */) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %45 = clip(%44, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %46 = cast(%45, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %47 = reshape(meta[relay.Constant][9] /* ty=Tensor[(256, 64, 1, 1), int8] */, newshape=[16, 16, 4, 16, 1, 1]) /* ty=Tensor[(16, 16, 4, 16, 1, 1), int8] */;
#   %48 = annotation.stop_fusion(%46) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %49 = transpose(%47, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(16, 4, 1, 1, 16, 16), int8] */;
#   %50 = nn.conv2d(%48, %49, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %51 = add(%50, 64 /* ty=int32 */) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %52 = right_shift(%51, 7 /* ty=int32 */) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %53 = clip(%52, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %54 = cast(%53, dtype="int8") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %55 = annotation.stop_fusion(%54) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %56 = annotation.stop_fusion(%16) /* ty=Tensor[(1, 4, 56, 56, 1, 16), float32] */;
#   %57 = multiply(%56, 16f /* ty=float32 */) /* ty=Tensor[(1, 4, 56, 56, 1, 16), float32] */;
#   %58 = round(%57) /* ty=Tensor[(1, 4, 56, 56, 1, 16), float32] */;
#   %59 = clip(%58, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 4, 56, 56, 1, 16), float32] */;
#   %60 = reshape(meta[relay.Constant][10] /* ty=Tensor[(256, 64, 1, 1), int8] */, newshape=[16, 16, 4, 16, 1, 1]) /* ty=Tensor[(16, 16, 4, 16, 1, 1), int8] */;
#   %61 = cast(%59, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %62 = transpose(%60, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(16, 4, 1, 1, 16, 16), int8] */;
#   %63 = nn.conv2d(%61, %62, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %64 = add(%63, 32 /* ty=int32 */) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %65 = right_shift(%64, 6 /* ty=int32 */) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %66 = clip(%65, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %67 = cast(%66, dtype="int8") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %68 = annotation.stop_fusion(%67) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %69 = cast(%55, dtype="int32") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %70 = cast(%68, dtype="int32") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %71 = add(%69, %70) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %72 = clip(%71, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %73 = cast(%72, dtype="int8") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %74 = annotation.stop_fusion(%73) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %75 = reshape(meta[relay.Constant][11] /* ty=Tensor[(256, 1, 1), int32] */, newshape=[16, 16, 1, 1, 1]) /* ty=Tensor[(16, 16, 1, 1, 1), int32] */;
#   %76 = transpose(%75, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %77 = cast(%74, dtype="int32") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %78 = broadcast_to(%76, shape=[16, 1, 1, 1, 16], dtype="") /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %79 = reshape(meta[relay.Constant][12] /* ty=Tensor[(256, 1, 1), int32] */, newshape=[16, 16, 1, 1, 1]) /* ty=Tensor[(16, 16, 1, 1, 1), int32] */;
#   %80 = transpose(%79, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %81 = multiply(%77, %78) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %82 = broadcast_to(%80, shape=[16, 1, 1, 1, 16], dtype="") /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %83 = add(%81, %82) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %84 = nn.relu(%83) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %85 = add(%84, 16 /* ty=int32 */) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %86 = right_shift(%85, 5 /* ty=int32 */) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %87 = clip(%86, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %88 = cast(%87, dtype="int8") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %89 = reshape(meta[relay.Constant][13] /* ty=Tensor[(64, 256, 1, 1), int8] */, newshape=[4, 16, 16, 16, 1, 1]) /* ty=Tensor[(4, 16, 16, 16, 1, 1), int8] */;
#   %90 = annotation.stop_fusion(%88) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %91 = transpose(%89, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(4, 16, 1, 1, 16, 16), int8] */;
#   %92 = reshape(meta[relay.Constant][14] /* ty=Tensor[(64, 1, 1), int32] */, newshape=[4, 16, 1, 1, 1]) /* ty=Tensor[(4, 16, 1, 1, 1), int32] */;
#   %93 = transpose(%92, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %94 = nn.conv2d(%90, %91, padding=[0, 0, 0, 0], channels=64, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %95 = broadcast_to(%93, shape=[4, 1, 1, 1, 16], dtype="") /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %96 = add(%94, %95) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %97 = nn.relu(%96) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %98 = add(%97, 32 /* ty=int32 */) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %99 = right_shift(%98, 6 /* ty=int32 */) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %100 = clip(%99, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %101 = cast(%100, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %102 = reshape(meta[relay.Constant][15] /* ty=Tensor[(64, 64, 3, 3), int8] */, newshape=[4, 16, 4, 16, 3, 3]) /* ty=Tensor[(4, 16, 4, 16, 3, 3), int8] */;
#   %103 = annotation.stop_fusion(%101) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %104 = transpose(%102, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(4, 4, 3, 3, 16, 16), int8] */;
#   %105 = reshape(meta[relay.Constant][16] /* ty=Tensor[(64, 1, 1), int32] */, newshape=[4, 16, 1, 1, 1]) /* ty=Tensor[(4, 16, 1, 1, 1), int32] */;
#   %106 = transpose(%105, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %107 = nn.conv2d(%103, %104, padding=[1, 1, 1, 1], channels=64, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %108 = broadcast_to(%106, shape=[4, 1, 1, 1, 16], dtype="") /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %109 = add(%107, %108) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %110 = nn.relu(%109) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %111 = add(%110, 64 /* ty=int32 */) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %112 = right_shift(%111, 7 /* ty=int32 */) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %113 = clip(%112, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %114 = cast(%113, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %115 = reshape(meta[relay.Constant][17] /* ty=Tensor[(256, 64, 1, 1), int8] */, newshape=[16, 16, 4, 16, 1, 1]) /* ty=Tensor[(16, 16, 4, 16, 1, 1), int8] */;
#   %116 = annotation.stop_fusion(%114) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %117 = transpose(%115, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(16, 4, 1, 1, 16, 16), int8] */;
#   %118 = nn.conv2d(%116, %117, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %119 = add(%118, 128 /* ty=int32 */) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %120 = right_shift(%119, 8 /* ty=int32 */) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %121 = clip(%120, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %122 = cast(%121, dtype="int8") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %123 = annotation.stop_fusion(%122) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %124 = cast(%72, dtype="int8") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %125 = annotation.stop_fusion(%124) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %126 = cast(%123, dtype="int32") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %127 = cast(%125, dtype="int32") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %128 = add(%126, %127) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %129 = clip(%128, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %130 = cast(%129, dtype="int8") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %131 = annotation.stop_fusion(%130) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %132 = reshape(meta[relay.Constant][18] /* ty=Tensor[(256, 1, 1), int32] */, newshape=[16, 16, 1, 1, 1]) /* ty=Tensor[(16, 16, 1, 1, 1), int32] */;
#   %133 = transpose(%132, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %134 = cast(%131, dtype="int32") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %135 = broadcast_to(%133, shape=[16, 1, 1, 1, 16], dtype="") /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %136 = reshape(meta[relay.Constant][19] /* ty=Tensor[(256, 1, 1), int32] */, newshape=[16, 16, 1, 1, 1]) /* ty=Tensor[(16, 16, 1, 1, 1), int32] */;
#   %137 = transpose(%136, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %138 = multiply(%134, %135) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %139 = broadcast_to(%137, shape=[16, 1, 1, 1, 16], dtype="") /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %140 = add(%138, %139) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %141 = nn.relu(%140) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %142 = add(%141, 32 /* ty=int32 */) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %143 = right_shift(%142, 6 /* ty=int32 */) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %144 = clip(%143, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %145 = cast(%144, dtype="int8") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %146 = reshape(meta[relay.Constant][20] /* ty=Tensor[(64, 256, 1, 1), int8] */, newshape=[4, 16, 16, 16, 1, 1]) /* ty=Tensor[(4, 16, 16, 16, 1, 1), int8] */;
#   %147 = annotation.stop_fusion(%145) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %148 = transpose(%146, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(4, 16, 1, 1, 16, 16), int8] */;
#   %149 = reshape(meta[relay.Constant][21] /* ty=Tensor[(64, 1, 1), int32] */, newshape=[4, 16, 1, 1, 1]) /* ty=Tensor[(4, 16, 1, 1, 1), int32] */;
#   %150 = transpose(%149, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %151 = nn.conv2d(%147, %148, padding=[0, 0, 0, 0], channels=64, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %152 = broadcast_to(%150, shape=[4, 1, 1, 1, 16], dtype="") /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %153 = add(%151, %152) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %154 = nn.relu(%153) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %155 = add(%154, 64 /* ty=int32 */) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %156 = right_shift(%155, 7 /* ty=int32 */) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %157 = clip(%156, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %158 = cast(%157, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %159 = reshape(meta[relay.Constant][22] /* ty=Tensor[(64, 64, 3, 3), int8] */, newshape=[4, 16, 4, 16, 3, 3]) /* ty=Tensor[(4, 16, 4, 16, 3, 3), int8] */;
#   %160 = annotation.stop_fusion(%158) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %161 = transpose(%159, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(4, 4, 3, 3, 16, 16), int8] */;
#   %162 = reshape(meta[relay.Constant][23] /* ty=Tensor[(64, 1, 1), int32] */, newshape=[4, 16, 1, 1, 1]) /* ty=Tensor[(4, 16, 1, 1, 1), int32] */;
#   %163 = transpose(%162, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %164 = nn.conv2d(%160, %161, padding=[1, 1, 1, 1], channels=64, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %165 = broadcast_to(%163, shape=[4, 1, 1, 1, 16], dtype="") /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %166 = add(%164, %165) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %167 = nn.relu(%166) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %168 = add(%167, 128 /* ty=int32 */) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %169 = right_shift(%168, 8 /* ty=int32 */) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %170 = clip(%169, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %171 = cast(%170, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %172 = reshape(meta[relay.Constant][24] /* ty=Tensor[(256, 64, 1, 1), int8] */, newshape=[16, 16, 4, 16, 1, 1]) /* ty=Tensor[(16, 16, 4, 16, 1, 1), int8] */;
#   %173 = annotation.stop_fusion(%171) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %174 = transpose(%172, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(16, 4, 1, 1, 16, 16), int8] */;
#   %175 = nn.conv2d(%173, %174, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %176 = add(%175, 128 /* ty=int32 */) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %177 = right_shift(%176, 8 /* ty=int32 */) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %178 = clip(%177, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %179 = cast(%178, dtype="int8") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %180 = annotation.stop_fusion(%179) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %181 = cast(%129, dtype="int8") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %182 = annotation.stop_fusion(%181) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %183 = cast(%180, dtype="int32") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %184 = cast(%182, dtype="int32") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %185 = add(%183, %184) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %186 = reshape(meta[relay.Constant][25] /* ty=Tensor[(256, 1, 1), int32] */, newshape=[16, 16, 1, 1, 1]) /* ty=Tensor[(16, 16, 1, 1, 1), int32] */;
#   %187 = transpose(%186, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %188 = left_shift(%185, 3 /* ty=int32 */) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %189 = broadcast_to(%187, shape=[16, 1, 1, 1, 16], dtype="") /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %190 = add(%188, %189) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %191 = nn.relu(%190) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %192 = add(%191, 4 /* ty=int32 */) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %193 = right_shift(%192, 3 /* ty=int32 */) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %194 = clip(%193, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int32] */;
#   %195 = cast(%194, dtype="int8") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %196 = reshape(meta[relay.Constant][26] /* ty=Tensor[(128, 256, 1, 1), int8] */, newshape=[8, 16, 16, 16, 1, 1]) /* ty=Tensor[(8, 16, 16, 16, 1, 1), int8] */;
#   %197 = annotation.stop_fusion(%195) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %198 = transpose(%196, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(8, 16, 1, 1, 16, 16), int8] */;
#   %199 = reshape(meta[relay.Constant][27] /* ty=Tensor[(128, 1, 1), int32] */, newshape=[8, 16, 1, 1, 1]) /* ty=Tensor[(8, 16, 1, 1, 1), int32] */;
#   %200 = transpose(%199, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %201 = nn.conv2d(%197, %198, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 8, 56, 56, 1, 16), int32] */;
#   %202 = broadcast_to(%200, shape=[8, 1, 1, 1, 16], dtype="") /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %203 = add(%201, %202) /* ty=Tensor[(1, 8, 56, 56, 1, 16), int32] */;
#   %204 = nn.relu(%203) /* ty=Tensor[(1, 8, 56, 56, 1, 16), int32] */;
#   %205 = add(%204, 32 /* ty=int32 */) /* ty=Tensor[(1, 8, 56, 56, 1, 16), int32] */;
#   %206 = right_shift(%205, 6 /* ty=int32 */) /* ty=Tensor[(1, 8, 56, 56, 1, 16), int32] */;
#   %207 = clip(%206, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 56, 56, 1, 16), int32] */;
#   %208 = cast(%207, dtype="int8") /* ty=Tensor[(1, 8, 56, 56, 1, 16), int8] */;
#   %209 = reshape(meta[relay.Constant][28] /* ty=Tensor[(128, 128, 3, 3), int8] */, newshape=[8, 16, 8, 16, 3, 3]) /* ty=Tensor[(8, 16, 8, 16, 3, 3), int8] */;
#   %210 = annotation.stop_fusion(%208) /* ty=Tensor[(1, 8, 56, 56, 1, 16), int8] */;
#   %211 = transpose(%209, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(8, 8, 3, 3, 16, 16), int8] */;
#   %212 = reshape(meta[relay.Constant][29] /* ty=Tensor[(128, 1, 1), int32] */, newshape=[8, 16, 1, 1, 1]) /* ty=Tensor[(8, 16, 1, 1, 1), int32] */;
#   %213 = transpose(%212, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %214 = nn.conv2d(%210, %211, strides=[2, 2], padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %215 = broadcast_to(%213, shape=[8, 1, 1, 1, 16], dtype="") /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %216 = add(%214, %215) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %217 = nn.relu(%216) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %218 = add(%217, 256 /* ty=int32 */) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %219 = right_shift(%218, 9 /* ty=int32 */) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %220 = clip(%219, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %221 = cast(%220, dtype="int8") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %222 = reshape(meta[relay.Constant][30] /* ty=Tensor[(512, 128, 1, 1), int8] */, newshape=[32, 16, 8, 16, 1, 1]) /* ty=Tensor[(32, 16, 8, 16, 1, 1), int8] */;
#   %223 = annotation.stop_fusion(%221) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %224 = transpose(%222, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(32, 8, 1, 1, 16, 16), int8] */;
#   %225 = nn.conv2d(%223, %224, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %226 = add(%225, 128 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %227 = right_shift(%226, 8 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %228 = clip(%227, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %229 = cast(%228, dtype="int8") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %230 = annotation.stop_fusion(%229) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %231 = cast(%194, dtype="int8") /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %232 = reshape(meta[relay.Constant][31] /* ty=Tensor[(512, 256, 1, 1), int8] */, newshape=[32, 16, 16, 16, 1, 1]) /* ty=Tensor[(32, 16, 16, 16, 1, 1), int8] */;
#   %233 = annotation.stop_fusion(%231) /* ty=Tensor[(1, 16, 56, 56, 1, 16), int8] */;
#   %234 = transpose(%232, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(32, 16, 1, 1, 16, 16), int8] */;
#   %235 = nn.conv2d(%233, %234, strides=[2, 2], padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %236 = add(%235, 128 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %237 = right_shift(%236, 8 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %238 = clip(%237, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %239 = cast(%238, dtype="int8") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %240 = annotation.stop_fusion(%239) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %241 = cast(%230, dtype="int32") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %242 = cast(%240, dtype="int32") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %243 = add(%241, %242) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %244 = clip(%243, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %245 = cast(%244, dtype="int8") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %246 = annotation.stop_fusion(%245) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %247 = reshape(meta[relay.Constant][32] /* ty=Tensor[(512, 1, 1), int32] */, newshape=[32, 16, 1, 1, 1]) /* ty=Tensor[(32, 16, 1, 1, 1), int32] */;
#   %248 = transpose(%247, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %249 = cast(%246, dtype="int32") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %250 = broadcast_to(%248, shape=[32, 1, 1, 1, 16], dtype="") /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %251 = reshape(meta[relay.Constant][33] /* ty=Tensor[(512, 1, 1), int32] */, newshape=[32, 16, 1, 1, 1]) /* ty=Tensor[(32, 16, 1, 1, 1), int32] */;
#   %252 = transpose(%251, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %253 = multiply(%249, %250) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %254 = broadcast_to(%252, shape=[32, 1, 1, 1, 16], dtype="") /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %255 = add(%253, %254) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %256 = nn.relu(%255) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %257 = add(%256, 16 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %258 = right_shift(%257, 5 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %259 = clip(%258, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %260 = cast(%259, dtype="int8") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %261 = reshape(meta[relay.Constant][34] /* ty=Tensor[(128, 512, 1, 1), int8] */, newshape=[8, 16, 32, 16, 1, 1]) /* ty=Tensor[(8, 16, 32, 16, 1, 1), int8] */;
#   %262 = annotation.stop_fusion(%260) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %263 = transpose(%261, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(8, 32, 1, 1, 16, 16), int8] */;
#   %264 = reshape(meta[relay.Constant][35] /* ty=Tensor[(128, 1, 1), int32] */, newshape=[8, 16, 1, 1, 1]) /* ty=Tensor[(8, 16, 1, 1, 1), int32] */;
#   %265 = transpose(%264, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %266 = nn.conv2d(%262, %263, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %267 = broadcast_to(%265, shape=[8, 1, 1, 1, 16], dtype="") /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %268 = add(%266, %267) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %269 = nn.relu(%268) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %270 = add(%269, 32 /* ty=int32 */) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %271 = right_shift(%270, 6 /* ty=int32 */) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %272 = clip(%271, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %273 = cast(%272, dtype="int8") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %274 = reshape(meta[relay.Constant][36] /* ty=Tensor[(128, 128, 3, 3), int8] */, newshape=[8, 16, 8, 16, 3, 3]) /* ty=Tensor[(8, 16, 8, 16, 3, 3), int8] */;
#   %275 = annotation.stop_fusion(%273) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %276 = transpose(%274, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(8, 8, 3, 3, 16, 16), int8] */;
#   %277 = reshape(meta[relay.Constant][37] /* ty=Tensor[(128, 1, 1), int32] */, newshape=[8, 16, 1, 1, 1]) /* ty=Tensor[(8, 16, 1, 1, 1), int32] */;
#   %278 = transpose(%277, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %279 = nn.conv2d(%275, %276, padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %280 = broadcast_to(%278, shape=[8, 1, 1, 1, 16], dtype="") /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %281 = add(%279, %280) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %282 = nn.relu(%281) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %283 = add(%282, 64 /* ty=int32 */) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %284 = right_shift(%283, 7 /* ty=int32 */) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %285 = clip(%284, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %286 = cast(%285, dtype="int8") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %287 = reshape(meta[relay.Constant][38] /* ty=Tensor[(512, 128, 1, 1), int8] */, newshape=[32, 16, 8, 16, 1, 1]) /* ty=Tensor[(32, 16, 8, 16, 1, 1), int8] */;
#   %288 = annotation.stop_fusion(%286) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %289 = transpose(%287, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(32, 8, 1, 1, 16, 16), int8] */;
#   %290 = nn.conv2d(%288, %289, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %291 = add(%290, 128 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %292 = right_shift(%291, 8 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %293 = clip(%292, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %294 = cast(%293, dtype="int8") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %295 = annotation.stop_fusion(%294) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %296 = cast(%244, dtype="int8") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %297 = annotation.stop_fusion(%296) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %298 = cast(%295, dtype="int32") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %299 = cast(%297, dtype="int32") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %300 = add(%298, %299) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %301 = clip(%300, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %302 = cast(%301, dtype="int8") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %303 = annotation.stop_fusion(%302) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %304 = reshape(meta[relay.Constant][39] /* ty=Tensor[(512, 1, 1), int32] */, newshape=[32, 16, 1, 1, 1]) /* ty=Tensor[(32, 16, 1, 1, 1), int32] */;
#   %305 = transpose(%304, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %306 = cast(%303, dtype="int32") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %307 = broadcast_to(%305, shape=[32, 1, 1, 1, 16], dtype="") /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %308 = reshape(meta[relay.Constant][40] /* ty=Tensor[(512, 1, 1), int32] */, newshape=[32, 16, 1, 1, 1]) /* ty=Tensor[(32, 16, 1, 1, 1), int32] */;
#   %309 = transpose(%308, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %310 = multiply(%306, %307) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %311 = broadcast_to(%309, shape=[32, 1, 1, 1, 16], dtype="") /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %312 = add(%310, %311) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %313 = nn.relu(%312) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %314 = add(%313, 16 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %315 = right_shift(%314, 5 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %316 = clip(%315, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %317 = cast(%316, dtype="int8") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %318 = reshape(meta[relay.Constant][41] /* ty=Tensor[(128, 512, 1, 1), int8] */, newshape=[8, 16, 32, 16, 1, 1]) /* ty=Tensor[(8, 16, 32, 16, 1, 1), int8] */;
#   %319 = annotation.stop_fusion(%317) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %320 = transpose(%318, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(8, 32, 1, 1, 16, 16), int8] */;
#   %321 = reshape(meta[relay.Constant][42] /* ty=Tensor[(128, 1, 1), int32] */, newshape=[8, 16, 1, 1, 1]) /* ty=Tensor[(8, 16, 1, 1, 1), int32] */;
#   %322 = transpose(%321, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %323 = nn.conv2d(%319, %320, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %324 = broadcast_to(%322, shape=[8, 1, 1, 1, 16], dtype="") /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %325 = add(%323, %324) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %326 = nn.relu(%325) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %327 = add(%326, 64 /* ty=int32 */) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %328 = right_shift(%327, 7 /* ty=int32 */) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %329 = clip(%328, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %330 = cast(%329, dtype="int8") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %331 = reshape(meta[relay.Constant][43] /* ty=Tensor[(128, 128, 3, 3), int8] */, newshape=[8, 16, 8, 16, 3, 3]) /* ty=Tensor[(8, 16, 8, 16, 3, 3), int8] */;
#   %332 = annotation.stop_fusion(%330) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %333 = transpose(%331, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(8, 8, 3, 3, 16, 16), int8] */;
#   %334 = reshape(meta[relay.Constant][44] /* ty=Tensor[(128, 1, 1), int32] */, newshape=[8, 16, 1, 1, 1]) /* ty=Tensor[(8, 16, 1, 1, 1), int32] */;
#   %335 = transpose(%334, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %336 = nn.conv2d(%332, %333, padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %337 = broadcast_to(%335, shape=[8, 1, 1, 1, 16], dtype="") /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %338 = add(%336, %337) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %339 = nn.relu(%338) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %340 = add(%339, 128 /* ty=int32 */) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %341 = right_shift(%340, 8 /* ty=int32 */) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %342 = clip(%341, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %343 = cast(%342, dtype="int8") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %344 = reshape(meta[relay.Constant][45] /* ty=Tensor[(512, 128, 1, 1), int8] */, newshape=[32, 16, 8, 16, 1, 1]) /* ty=Tensor[(32, 16, 8, 16, 1, 1), int8] */;
#   %345 = annotation.stop_fusion(%343) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %346 = transpose(%344, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(32, 8, 1, 1, 16, 16), int8] */;
#   %347 = nn.conv2d(%345, %346, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %348 = add(%347, 128 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %349 = right_shift(%348, 8 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %350 = clip(%349, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %351 = cast(%350, dtype="int8") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %352 = annotation.stop_fusion(%351) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %353 = cast(%301, dtype="int8") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %354 = annotation.stop_fusion(%353) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %355 = cast(%352, dtype="int32") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %356 = cast(%354, dtype="int32") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %357 = add(%355, %356) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %358 = clip(%357, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %359 = cast(%358, dtype="int8") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %360 = annotation.stop_fusion(%359) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %361 = reshape(meta[relay.Constant][46] /* ty=Tensor[(512, 1, 1), int32] */, newshape=[32, 16, 1, 1, 1]) /* ty=Tensor[(32, 16, 1, 1, 1), int32] */;
#   %362 = transpose(%361, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %363 = cast(%360, dtype="int32") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %364 = broadcast_to(%362, shape=[32, 1, 1, 1, 16], dtype="") /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %365 = reshape(meta[relay.Constant][47] /* ty=Tensor[(512, 1, 1), int32] */, newshape=[32, 16, 1, 1, 1]) /* ty=Tensor[(32, 16, 1, 1, 1), int32] */;
#   %366 = transpose(%365, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %367 = multiply(%363, %364) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %368 = broadcast_to(%366, shape=[32, 1, 1, 1, 16], dtype="") /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %369 = add(%367, %368) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %370 = nn.relu(%369) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %371 = add(%370, 32 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %372 = right_shift(%371, 6 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %373 = clip(%372, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %374 = cast(%373, dtype="int8") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %375 = reshape(meta[relay.Constant][48] /* ty=Tensor[(128, 512, 1, 1), int8] */, newshape=[8, 16, 32, 16, 1, 1]) /* ty=Tensor[(8, 16, 32, 16, 1, 1), int8] */;
#   %376 = annotation.stop_fusion(%374) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %377 = transpose(%375, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(8, 32, 1, 1, 16, 16), int8] */;
#   %378 = reshape(meta[relay.Constant][49] /* ty=Tensor[(128, 1, 1), int32] */, newshape=[8, 16, 1, 1, 1]) /* ty=Tensor[(8, 16, 1, 1, 1), int32] */;
#   %379 = transpose(%378, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %380 = nn.conv2d(%376, %377, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %381 = broadcast_to(%379, shape=[8, 1, 1, 1, 16], dtype="") /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %382 = add(%380, %381) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %383 = nn.relu(%382) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %384 = add(%383, 64 /* ty=int32 */) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %385 = right_shift(%384, 7 /* ty=int32 */) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %386 = clip(%385, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %387 = cast(%386, dtype="int8") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %388 = reshape(meta[relay.Constant][50] /* ty=Tensor[(128, 128, 3, 3), int8] */, newshape=[8, 16, 8, 16, 3, 3]) /* ty=Tensor[(8, 16, 8, 16, 3, 3), int8] */;
#   %389 = annotation.stop_fusion(%387) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %390 = transpose(%388, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(8, 8, 3, 3, 16, 16), int8] */;
#   %391 = reshape(meta[relay.Constant][51] /* ty=Tensor[(128, 1, 1), int32] */, newshape=[8, 16, 1, 1, 1]) /* ty=Tensor[(8, 16, 1, 1, 1), int32] */;
#   %392 = transpose(%391, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %393 = nn.conv2d(%389, %390, padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %394 = broadcast_to(%392, shape=[8, 1, 1, 1, 16], dtype="") /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %395 = add(%393, %394) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %396 = nn.relu(%395) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %397 = add(%396, 64 /* ty=int32 */) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %398 = right_shift(%397, 7 /* ty=int32 */) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %399 = clip(%398, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %400 = cast(%399, dtype="int8") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %401 = reshape(meta[relay.Constant][52] /* ty=Tensor[(512, 128, 1, 1), int8] */, newshape=[32, 16, 8, 16, 1, 1]) /* ty=Tensor[(32, 16, 8, 16, 1, 1), int8] */;
#   %402 = annotation.stop_fusion(%400) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %403 = transpose(%401, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(32, 8, 1, 1, 16, 16), int8] */;
#   %404 = nn.conv2d(%402, %403, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %405 = add(%404, 128 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %406 = right_shift(%405, 8 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %407 = clip(%406, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %408 = cast(%407, dtype="int8") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %409 = annotation.stop_fusion(%408) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %410 = cast(%358, dtype="int8") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %411 = annotation.stop_fusion(%410) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %412 = cast(%409, dtype="int32") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %413 = cast(%411, dtype="int32") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %414 = add(%412, %413) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %415 = reshape(meta[relay.Constant][53] /* ty=Tensor[(512, 1, 1), int32] */, newshape=[32, 16, 1, 1, 1]) /* ty=Tensor[(32, 16, 1, 1, 1), int32] */;
#   %416 = transpose(%415, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %417 = left_shift(%414, 4 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %418 = broadcast_to(%416, shape=[32, 1, 1, 1, 16], dtype="") /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %419 = add(%417, %418) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %420 = nn.relu(%419) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %421 = add(%420, 8 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %422 = right_shift(%421, 4 /* ty=int32 */) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %423 = clip(%422, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int32] */;
#   %424 = cast(%423, dtype="int8") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %425 = reshape(meta[relay.Constant][54] /* ty=Tensor[(256, 512, 1, 1), int8] */, newshape=[16, 16, 32, 16, 1, 1]) /* ty=Tensor[(16, 16, 32, 16, 1, 1), int8] */;
#   %426 = annotation.stop_fusion(%424) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %427 = transpose(%425, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(16, 32, 1, 1, 16, 16), int8] */;
#   %428 = reshape(meta[relay.Constant][55] /* ty=Tensor[(256, 1, 1), int32] */, newshape=[16, 16, 1, 1, 1]) /* ty=Tensor[(16, 16, 1, 1, 1), int32] */;
#   %429 = transpose(%428, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %430 = nn.conv2d(%426, %427, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 16, 28, 28, 1, 16), int32] */;
#   %431 = broadcast_to(%429, shape=[16, 1, 1, 1, 16], dtype="") /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %432 = add(%430, %431) /* ty=Tensor[(1, 16, 28, 28, 1, 16), int32] */;
#   %433 = nn.relu(%432) /* ty=Tensor[(1, 16, 28, 28, 1, 16), int32] */;
#   %434 = add(%433, 32 /* ty=int32 */) /* ty=Tensor[(1, 16, 28, 28, 1, 16), int32] */;
#   %435 = right_shift(%434, 6 /* ty=int32 */) /* ty=Tensor[(1, 16, 28, 28, 1, 16), int32] */;
#   %436 = clip(%435, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 16, 28, 28, 1, 16), int32] */;
#   %437 = cast(%436, dtype="int8") /* ty=Tensor[(1, 16, 28, 28, 1, 16), int8] */;
#   %438 = reshape(meta[relay.Constant][56] /* ty=Tensor[(256, 256, 3, 3), int8] */, newshape=[16, 16, 16, 16, 3, 3]) /* ty=Tensor[(16, 16, 16, 16, 3, 3), int8] */;
#   %439 = annotation.stop_fusion(%437) /* ty=Tensor[(1, 16, 28, 28, 1, 16), int8] */;
#   %440 = transpose(%438, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(16, 16, 3, 3, 16, 16), int8] */;
#   %441 = reshape(meta[relay.Constant][57] /* ty=Tensor[(256, 1, 1), int32] */, newshape=[16, 16, 1, 1, 1]) /* ty=Tensor[(16, 16, 1, 1, 1), int32] */;
#   %442 = transpose(%441, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %443 = nn.conv2d(%439, %440, strides=[2, 2], padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %444 = broadcast_to(%442, shape=[16, 1, 1, 1, 16], dtype="") /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %445 = add(%443, %444) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %446 = nn.relu(%445) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %447 = add(%446, 256 /* ty=int32 */) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %448 = right_shift(%447, 9 /* ty=int32 */) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %449 = clip(%448, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %450 = cast(%449, dtype="int8") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %451 = reshape(meta[relay.Constant][58] /* ty=Tensor[(1024, 256, 1, 1), int8] */, newshape=[64, 16, 16, 16, 1, 1]) /* ty=Tensor[(64, 16, 16, 16, 1, 1), int8] */;
#   %452 = annotation.stop_fusion(%450) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %453 = transpose(%451, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(64, 16, 1, 1, 16, 16), int8] */;
#   %454 = nn.conv2d(%452, %453, padding=[0, 0, 0, 0], channels=1024, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 64, 14, 14, 1, 16), int32] */;
#   %455 = add(%454, 128 /* ty=int32 */) /* ty=Tensor[(1, 64, 14, 14, 1, 16), int32] */;
#   %456 = right_shift(%455, 8 /* ty=int32 */) /* ty=Tensor[(1, 64, 14, 14, 1, 16), int32] */;
#   %457 = clip(%456, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 64, 14, 14, 1, 16), int32] */;
#   %458 = cast(%457, dtype="int8") /* ty=Tensor[(1, 64, 14, 14, 1, 16), int8] */;
#   %459 = annotation.stop_fusion(%458) /* ty=Tensor[(1, 64, 14, 14, 1, 16), int8] */;
#   %460 = cast(%423, dtype="int8") /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %461 = reshape(meta[relay.Constant][59] /* ty=Tensor[(1024, 512, 1, 1), int8] */, newshape=[64, 16, 32, 16, 1, 1]) /* ty=Tensor[(64, 16, 32, 16, 1, 1), int8] */;
#   %462 = annotation.stop_fusion(%460) /* ty=Tensor[(1, 32, 28, 28, 1, 16), int8] */;
#   %463 = transpose(%461, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(64, 32, 1, 1, 16, 16), int8] */;
#   %464 = nn.conv2d(%462, %463, strides=[2, 2], padding=[0, 0, 0, 0], channels=1024, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 64, 14, 14, 1, 16), int32] */;
#   %465 = add(%464, 64 /* ty=int32 */) /* ty=Tensor[(1, 64, 14, 14, 1, 16), int32] */;
#   %466 = right_shift(%465, 7 /* ty=int32 */) /* ty=Tensor[(1, 64, 14, 14, 1, 16), int32] */;
#   %467 = clip(%466, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 64, 14, 14, 1, 16), int32] */;
#   %468 = cast(%467, dtype="int8") /* ty=Tensor[(1, 64, 14, 14, 1, 16), int8] */;
# ...
#   %798 = add(%797, 64 /* ty=int32 */) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %799 = right_shift(%798, 7 /* ty=int32 */) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %800 = clip(%799, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %801 = cast(%800, dtype="int8") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %802 = annotation.stop_fusion(%801) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %803 = cast(%766, dtype="int8") /* ty=Tensor[(1, 64, 14, 14, 1, 16), int8] */;
#   %804 = reshape(meta[relay.Constant][101] /* ty=Tensor[(2048, 1024, 1, 1), int8] */, newshape=[128, 16, 64, 16, 1, 1]) /* ty=Tensor[(128, 16, 64, 16, 1, 1), int8] */;
#   %805 = annotation.stop_fusion(%803) /* ty=Tensor[(1, 64, 14, 14, 1, 16), int8] */;
#   %806 = transpose(%804, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(128, 64, 1, 1, 16, 16), int8] */;
#   %807 = nn.conv2d(%805, %806, strides=[2, 2], padding=[0, 0, 0, 0], channels=2048, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %808 = add(%807, 32 /* ty=int32 */) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %809 = right_shift(%808, 6 /* ty=int32 */) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %810 = clip(%809, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %811 = cast(%810, dtype="int8") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %812 = annotation.stop_fusion(%811) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %813 = cast(%802, dtype="int32") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %814 = cast(%812, dtype="int32") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %815 = add(%813, %814) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %816 = clip(%815, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %817 = cast(%816, dtype="int8") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %818 = annotation.stop_fusion(%817) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %819 = reshape(meta[relay.Constant][102] /* ty=Tensor[(2048, 1, 1), int32] */, newshape=[128, 16, 1, 1, 1]) /* ty=Tensor[(128, 16, 1, 1, 1), int32] */;
#   %820 = transpose(%819, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(128, 1, 1, 1, 16), int32] */;
#   %821 = cast(%818, dtype="int32") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %822 = broadcast_to(%820, shape=[128, 1, 1, 1, 16], dtype="") /* ty=Tensor[(128, 1, 1, 1, 16), int32] */;
#   %823 = reshape(meta[relay.Constant][103] /* ty=Tensor[(2048, 1, 1), int32] */, newshape=[128, 16, 1, 1, 1]) /* ty=Tensor[(128, 16, 1, 1, 1), int32] */;
#   %824 = transpose(%823, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(128, 1, 1, 1, 16), int32] */;
#   %825 = multiply(%821, %822) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %826 = broadcast_to(%824, shape=[128, 1, 1, 1, 16], dtype="") /* ty=Tensor[(128, 1, 1, 1, 16), int32] */;
#   %827 = add(%825, %826) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %828 = nn.relu(%827) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %829 = add(%828, 8 /* ty=int32 */) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %830 = right_shift(%829, 4 /* ty=int32 */) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %831 = clip(%830, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %832 = cast(%831, dtype="int8") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %833 = reshape(meta[relay.Constant][104] /* ty=Tensor[(512, 2048, 1, 1), int8] */, newshape=[32, 16, 128, 16, 1, 1]) /* ty=Tensor[(32, 16, 128, 16, 1, 1), int8] */;
#   %834 = annotation.stop_fusion(%832) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %835 = transpose(%833, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(32, 128, 1, 1, 16, 16), int8] */;
#   %836 = reshape(meta[relay.Constant][105] /* ty=Tensor[(512, 1, 1), int32] */, newshape=[32, 16, 1, 1, 1]) /* ty=Tensor[(32, 16, 1, 1, 1), int32] */;
#   %837 = transpose(%836, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %838 = nn.conv2d(%834, %835, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %839 = broadcast_to(%837, shape=[32, 1, 1, 1, 16], dtype="") /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %840 = add(%838, %839) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %841 = nn.relu(%840) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %842 = add(%841, 32 /* ty=int32 */) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %843 = right_shift(%842, 6 /* ty=int32 */) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %844 = clip(%843, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %845 = cast(%844, dtype="int8") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %846 = reshape(meta[relay.Constant][106] /* ty=Tensor[(512, 512, 3, 3), int8] */, newshape=[32, 16, 32, 16, 3, 3]) /* ty=Tensor[(32, 16, 32, 16, 3, 3), int8] */;
#   %847 = annotation.stop_fusion(%845) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %848 = transpose(%846, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(32, 32, 3, 3, 16, 16), int8] */;
#   %849 = reshape(meta[relay.Constant][107] /* ty=Tensor[(512, 1, 1), int32] */, newshape=[32, 16, 1, 1, 1]) /* ty=Tensor[(32, 16, 1, 1, 1), int32] */;
#   %850 = transpose(%849, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %851 = nn.conv2d(%847, %848, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %852 = broadcast_to(%850, shape=[32, 1, 1, 1, 16], dtype="") /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %853 = add(%851, %852) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %854 = nn.relu(%853) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %855 = add(%854, 256 /* ty=int32 */) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %856 = right_shift(%855, 9 /* ty=int32 */) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %857 = clip(%856, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %858 = cast(%857, dtype="int8") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %859 = reshape(meta[relay.Constant][108] /* ty=Tensor[(2048, 512, 1, 1), int8] */, newshape=[128, 16, 32, 16, 1, 1]) /* ty=Tensor[(128, 16, 32, 16, 1, 1), int8] */;
#   %860 = annotation.stop_fusion(%858) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %861 = transpose(%859, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(128, 32, 1, 1, 16, 16), int8] */;
#   %862 = nn.conv2d(%860, %861, padding=[0, 0, 0, 0], channels=2048, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %863 = add(%862, 128 /* ty=int32 */) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %864 = right_shift(%863, 8 /* ty=int32 */) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %865 = clip(%864, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %866 = cast(%865, dtype="int8") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %867 = annotation.stop_fusion(%866) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %868 = cast(%816, dtype="int8") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %869 = annotation.stop_fusion(%868) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %870 = cast(%867, dtype="int32") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %871 = cast(%869, dtype="int32") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %872 = add(%870, %871) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %873 = clip(%872, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %874 = cast(%873, dtype="int8") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %875 = annotation.stop_fusion(%874) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %876 = reshape(meta[relay.Constant][109] /* ty=Tensor[(2048, 1, 1), int32] */, newshape=[128, 16, 1, 1, 1]) /* ty=Tensor[(128, 16, 1, 1, 1), int32] */;
#   %877 = transpose(%876, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(128, 1, 1, 1, 16), int32] */;
#   %878 = cast(%875, dtype="int32") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %879 = broadcast_to(%877, shape=[128, 1, 1, 1, 16], dtype="") /* ty=Tensor[(128, 1, 1, 1, 16), int32] */;
#   %880 = reshape(meta[relay.Constant][110] /* ty=Tensor[(2048, 1, 1), int32] */, newshape=[128, 16, 1, 1, 1]) /* ty=Tensor[(128, 16, 1, 1, 1), int32] */;
#   %881 = transpose(%880, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(128, 1, 1, 1, 16), int32] */;
#   %882 = multiply(%878, %879) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %883 = broadcast_to(%881, shape=[128, 1, 1, 1, 16], dtype="") /* ty=Tensor[(128, 1, 1, 1, 16), int32] */;
#   %884 = add(%882, %883) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %885 = nn.relu(%884) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %886 = add(%885, 8 /* ty=int32 */) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %887 = right_shift(%886, 4 /* ty=int32 */) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %888 = clip(%887, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %889 = cast(%888, dtype="int8") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %890 = reshape(meta[relay.Constant][111] /* ty=Tensor[(512, 2048, 1, 1), int8] */, newshape=[32, 16, 128, 16, 1, 1]) /* ty=Tensor[(32, 16, 128, 16, 1, 1), int8] */;
#   %891 = annotation.stop_fusion(%889) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %892 = transpose(%890, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(32, 128, 1, 1, 16, 16), int8] */;
#   %893 = reshape(meta[relay.Constant][112] /* ty=Tensor[(512, 1, 1), int32] */, newshape=[32, 16, 1, 1, 1]) /* ty=Tensor[(32, 16, 1, 1, 1), int32] */;
#   %894 = transpose(%893, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %895 = nn.conv2d(%891, %892, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %896 = broadcast_to(%894, shape=[32, 1, 1, 1, 16], dtype="") /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %897 = add(%895, %896) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %898 = nn.relu(%897) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %899 = add(%898, 16 /* ty=int32 */) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %900 = right_shift(%899, 5 /* ty=int32 */) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %901 = clip(%900, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %902 = cast(%901, dtype="int8") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %903 = reshape(meta[relay.Constant][113] /* ty=Tensor[(512, 512, 3, 3), int8] */, newshape=[32, 16, 32, 16, 3, 3]) /* ty=Tensor[(32, 16, 32, 16, 3, 3), int8] */;
#   %904 = annotation.stop_fusion(%902) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %905 = transpose(%903, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(32, 32, 3, 3, 16, 16), int8] */;
#   %906 = reshape(meta[relay.Constant][114] /* ty=Tensor[(512, 1, 1), int32] */, newshape=[32, 16, 1, 1, 1]) /* ty=Tensor[(32, 16, 1, 1, 1), int32] */;
#   %907 = transpose(%906, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %908 = nn.conv2d(%904, %905, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %909 = broadcast_to(%907, shape=[32, 1, 1, 1, 16], dtype="") /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %910 = add(%908, %909) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %911 = nn.relu(%910) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %912 = add(%911, 32 /* ty=int32 */) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %913 = right_shift(%912, 6 /* ty=int32 */) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %914 = clip(%913, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %915 = cast(%914, dtype="int8") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %916 = reshape(meta[relay.Constant][115] /* ty=Tensor[(2048, 512, 1, 1), int8] */, newshape=[128, 16, 32, 16, 1, 1]) /* ty=Tensor[(128, 16, 32, 16, 1, 1), int8] */;
#   %917 = annotation.stop_fusion(%915) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %918 = transpose(%916, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(128, 32, 1, 1, 16, 16), int8] */;
#   %919 = nn.conv2d(%917, %918, padding=[0, 0, 0, 0], channels=2048, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %920 = add(%919, 64 /* ty=int32 */) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %921 = right_shift(%920, 7 /* ty=int32 */) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %922 = clip(%921, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %923 = cast(%922, dtype="int8") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %924 = annotation.stop_fusion(%923) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %925 = cast(%873, dtype="int8") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %926 = annotation.stop_fusion(%925) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %927 = cast(%924, dtype="int32") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %928 = cast(%926, dtype="int32") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %929 = add(%927, %928) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %930 = cast(%929, dtype="int8") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %931 = annotation.stop_fusion(%930) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %932 = reshape(meta[relay.Constant][116] /* ty=Tensor[(2048, 1, 1), int32] */, newshape=[128, 16, 1, 1, 1]) /* ty=Tensor[(128, 16, 1, 1, 1), int32] */;
#   %933 = transpose(%932, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(128, 1, 1, 1, 16), int32] */;
#   %934 = cast(%931, dtype="int32") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %935 = broadcast_to(%933, shape=[128, 1, 1, 1, 16], dtype="") /* ty=Tensor[(128, 1, 1, 1, 16), int32] */;
#   %936 = reshape(meta[relay.Constant][117] /* ty=Tensor[(2048, 1, 1), int32] */, newshape=[128, 16, 1, 1, 1]) /* ty=Tensor[(128, 16, 1, 1, 1), int32] */;
#   %937 = transpose(%936, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(128, 1, 1, 1, 16), int32] */;
#   %938 = multiply(%934, %935) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %939 = broadcast_to(%937, shape=[128, 1, 1, 1, 16], dtype="") /* ty=Tensor[(128, 1, 1, 1, 16), int32] */;
#   %940 = add(%938, %939) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %941 = nn.relu(%940) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %942 = add(%941, 4 /* ty=int32 */) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %943 = right_shift(%942, 3 /* ty=int32 */) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %944 = clip(%943, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %945 = cast(%944, dtype="int8") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %946 = annotation.stop_fusion(%945) /* ty=Tensor[(1, 128, 7, 7, 1, 16), int8] */;
#   %947 = cast(%946, dtype="int32") /* ty=Tensor[(1, 128, 7, 7, 1, 16), int32] */;
#   %948 = transpose(%947, axes=[0, 4, 1, 5, 2, 3]) /* ty=Tensor[(1, 1, 128, 16, 7, 7), int32] */;
#   %949 = reshape(%948, newshape=[1, 2048, 7, 7]) /* ty=Tensor[(1, 2048, 7, 7), int32] */;
#   %950 = nn.global_avg_pool2d(%949) /* ty=Tensor[(1, 2048, 1, 1), int32] */;
#   %951 = nn.batch_flatten(%950) /* ty=Tensor[(1, 2048), int32] */;
#   %952 = nn.batch_flatten(%951) /* ty=Tensor[(1, 2048), int32] */;
#   %953 = cast(%952, dtype="float32") /* ty=Tensor[(1, 2048), float32] */;
#   %954 = multiply(%953, 0.0625f /* ty=float32 */) /* ty=Tensor[(1, 2048), float32] */;
#   %955 = nn.dense(%954, meta[relay.Constant][118] /* ty=Tensor[(1000, 2048), float32] */, units=1000) /* ty=Tensor[(1, 1000), float32] */;
#   add(%955, meta[relay.Constant][119] /* ty=Tensor[(1000), float32] */) /* ty=Tensor[(1, 1000), float32] */
# }
#
# /* For debugging purposes the metadata section has been omitted.
#  * If you would like to see the full metadata section you can set the
#  * option to `True` when invoking `astext`.
#  */
