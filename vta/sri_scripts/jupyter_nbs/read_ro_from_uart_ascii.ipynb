# %%
ro_values = []
with open("/home/srchand/resnet_uart_ascii_100.log", 'rb') as myfile:
    while(line := myfile.readline()):
        if(int(line)<=2097152):
           ro_values.append(int(line))

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame(ro_values)

# %%
df.plot(subplots=True, figsize=(40,10))
# Out:
# array([<AxesSubplot:>], dtype=object)
