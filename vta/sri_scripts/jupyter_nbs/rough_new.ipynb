# %%
import numpy as np
row = [0]*340
old = [row]*200

# %%
broken_175000 = ['network_2_set_0', 'network_134_set_0', 'network_111_set_0', 'network_62_set_0', 'network_43_set_0', 'network_68_set_0', 'network_22_set_0', 'network_26_set_0', 'network_192_set_0', 'network_59_set_0', 'network_36_set_0', 'network_146_set_0']
len(broken_175000)
# Out:
# 12

# %%
broken_1x16x16_175000 = ['network_111_set_0', 'network_148_set_0', 'network_168_set_0', 'network_92_set_0', 'network_82_set_0', 'network_123_set_0', 'network_93_set_0', 'network_85_set_0', 'network_187_set_0', 'network_35_set_0', 'network_56_set_0', 'network_89_set_0', 'network_151_set_0', 'network_29_set_0', 'network_135_set_0', 'network_107_set_0', 'network_192_set_0', 'network_125_set_0', 'network_124_set_0', 'network_13_set_0', 'network_182_set_0', 'network_20_set_0', 'network_47_set_0', 'network_28_set_0', 'network_133_set_0', 'network_149_set_0', 'network_98_set_0', 'network_144_set_0', 'network_190_set_0', 'network_106_set_0', 'network_118_set_0', 'network_88_set_0', 'network_68_set_0', 'network_46_set_0', 'network_102_set_0', 'network_160_set_0', 'network_73_set_0', 'network_75_set_0', 'network_170_set_0', 'network_185_set_0', 'network_186_set_0', 'network_60_set_0', 'network_59_set_0', 'network_121_set_0', 'network_94_set_0', 'network_105_set_0', 'network_41_set_0', 'network_176_set_0', 'network_150_set_0', 'network_131_set_0', 'network_33_set_0', 'network_37_set_0', 'network_27_set_0', 'network_100_set_0']


len(broken_1x16x16_175000)
# Out:
# 54

# %%
broken_1x16x16_10000 = ['network_68_set_0', 'network_171_set_0', 'network_173_set_0', 'network_84_set_0', 'network_140_set_0', 'network_150_set_0', 'network_32_set_0', 'network_212_set_0', 'network_159_set_0', 'network_61_set_0', 'network_51_set_0', 'network_65_set_0', 'network_11_set_0', 'network_94_set_0', 'network_52_set_0', 'network_91_set_0', 'network_114_set_0', 'network_18_set_0', 'network_81_set_0', 'network_201_set_0', 'network_4_set_0', 'network_41_set_0', 'network_13_set_0', 'network_170_set_0', 'network_191_set_0', 'network_193_set_0', 'network_153_set_0', 'network_124_set_0', 'network_54_set_0', 'network_27_set_0', 'network_123_set_0', 'network_5_set_0', 'network_71_set_0', 'network_149_set_0', 'network_113_set_0', 'network_162_set_0', 'network_130_set_0', 'network_75_set_0', 'network_31_set_0', 'network_198_set_0', 'network_73_set_0', 'network_121_set_0', 'network_98_set_0', 'network_104_set_0', 'network_145_set_0', 'network_10_set_0', 'network_203_set_0', 'network_188_set_0', 'network_66_set_0']

len(broken_1x16x16_10000)
# Out:
# 49

# %%
broken_4x8x8_10000 = ['network_172_set_0', 'network_157_set_0', 'network_97_set_0', 'network_174_set_0', 'network_107_set_0', 'network_188_set_0', 'network_150_set_0', 'network_89_set_0', 'network_177_set_0', 'network_53_set_0', 'network_129_set_0', 'network_119_set_0', 'network_87_set_0', 'network_34_set_0', 'network_51_set_0', 'network_55_set_0', 'network_54_set_0', 'network_143_set_0', 'network_101_set_0', 'network_78_set_0', 'network_176_set_0', 'network_152_set_0', 'network_23_set_0', 'network_103_set_0', 'network_59_set_0', 'network_128_set_0', 'network_108_set_0', 'network_13_set_0', 'network_58_set_0', 'network_77_set_0', 'network_137_set_0', 'network_122_set_0', 'network_47_set_0', 'network_115_set_0', 'network_159_set_0', 'network_32_set_0', 'network_110_set_0', 'network_37_set_0', 'network_123_set_0', 'network_95_set_0', 'network_60_set_0', 'network_33_set_0', 'network_61_set_0', 'network_120_set_0', 'network_160_set_0', 'network_36_set_0', 'network_168_set_0', 'network_6_set_0', 'network_27_set_0', 'network_106_set_0', 'network_75_set_0', 'network_45_set_0', 'network_169_set_0', 'network_179_set_0', 'network_161_set_0', 'network_70_set_0', 'network_90_set_0', 'network_17_set_0', 'network_56_set_0', 'network_11_set_0', 'network_73_set_0', 'network_72_set_0', 'network_21_set_0', 'network_134_set_0', 'network_92_set_0', 'network_22_set_0', 'network_121_set_0', 'network_84_set_0', 'network_165_set_0', 'network_8_set_0', 'network_57_set_0', 'network_113_set_0', 'network_74_set_0', 'network_180_set_0', 'network_25_set_0', 'network_142_set_0', 'network_96_set_0', 'network_91_set_0', 'network_63_set_0', 'network_40_set_0', 'network_1_set_0', 'network_130_set_0', 'network_0_set_0', 'network_71_set_0', 'network_167_set_0', 'network_146_set_0', 'network_127_set_0', 'network_15_set_0', 'network_39_set_0', 'network_136_set_0', 'network_94_set_0', 'network_67_set_0', 'network_69_set_0', 'network_31_set_0', 'network_19_set_0', 'network_131_set_0', 'network_162_set_0', 'network_182_set_0', 'network_3_set_0', 'network_76_set_0', 'network_125_set_0', 'network_102_set_0', 'network_189_set_0', 'network_28_set_0', 'network_14_set_0', 'network_170_set_0', 'network_173_set_0', 'network_41_set_0', 'network_158_set_0', 'network_48_set_0', 'network_44_set_0', 'network_155_set_0', 'network_9_set_0', 'network_118_set_0', 'network_139_set_0', 'network_148_set_0', 'network_85_set_0', 'network_16_set_0', 'network_26_set_0', 'network_38_set_0', 'network_140_set_0', 'network_93_set_0']
len(broken_4x8x8_10000)
# Out:
# 122

# %%
broken_4x8x8_75000_333 = ['network_129_set_0', 'network_162_set_0', 'network_142_set_0', 'network_114_set_0', 'network_46_set_0', 'network_239_set_0', 'network_169_set_0', 'network_194_set_0', 'network_202_set_0', 'network_126_set_0', 'network_58_set_0', 'network_144_set_0', 'network_32_set_0', 'network_10_set_0', 'network_244_set_0', 'network_130_set_0', 'network_104_set_0', 'network_195_set_0', 'network_136_set_0', 'network_70_set_0', 'network_240_set_0', 'network_210_set_0', 'network_189_set_0', 'network_225_set_0', 'network_242_set_0', 'network_197_set_0', 'network_173_set_0', 'network_75_set_0', 'network_249_set_0', 'network_102_set_0', 'network_208_set_0', 'network_106_set_0', 'network_175_set_0', 'network_243_set_0', 'network_115_set_0', 'network_122_set_0', 'network_60_set_0', 'network_203_set_0', 'network_72_set_0', 'network_85_set_0', 'network_156_set_0', 'network_86_set_0', 'network_248_set_0', 'network_245_set_0', 'network_25_set_0', 'network_167_set_0', 'network_83_set_0', 'network_246_set_0', 'network_105_set_0', 'network_27_set_0', 'network_8_set_0', 'network_183_set_0', 'network_233_set_0', 'network_231_set_0', 'network_247_set_0', 'network_180_set_0', 'network_219_set_0', 'network_170_set_0', 'network_91_set_0', 'network_241_set_0', 'network_164_set_0', 'network_11_set_0', 'network_222_set_0', 'network_186_set_0', 'network_63_set_0', 'network_166_set_0', 'network_139_set_0', 'network_103_set_0', 'network_30_set_0', 'network_184_set_0']
len(broken_4x8x8_75000_333)
# Out:
# 70

# %%
new = [row] * 100

# %%
len(old[0])
# Out:
# 340

# %%
arr=np.array([0,0,0,0,0,0,0,0])

# %%
arr[4:6]
# Out:
# array([0, 0])

# %%
Finished_files =  ['network_410.csv', 'network_552.csv', 'network_474.csv', 'network_197.csv', 'network_744.csv', 'network_571.csv', 'network_266.csv', 'network_122.csv', 'network_620.csv', 'network_21.csv', 'network_449.csv', 'network_691.csv', 'network_326.csv', 'network_471.csv', 'network_518.csv', 'network_509.csv', 'network_330.csv', 'network_316.csv', 'network_455.csv', 'network_494.csv', 'network_463.csv', 'network_721.csv', 'network_95.csv', 'network_739.csv', 'network_56.csv', 'network_154.csv', 'network_621.csv', 'network_661.csv', 'network_766.csv', 'network_608.csv', 'network_703.csv', 'network_488.csv', 'network_205.csv', 'network_487.csv', 'network_175.csv', 'network_670.csv', 'network_593.csv', 'network_291.csv', 'network_448.csv', 'network_57.csv', 'network_656.csv', 'network_514.csv']
len(Finished_files)
# Out:
# 42

# %%
int('network_15.csv'.split('.')[0].split('_')[1].strip())
# Out:
# 15

# %%
files=  ['network_410.csv', 'network_552.csv', 'network_474.csv', 'network_197.csv', 'network_744.csv', 'network_571.csv', 'network_266.csv', 'network_122.csv', 'network_620.csv', 'network_21.csv', 'network_449.csv', 'network_691.csv', 'network_326.csv', 'network_471.csv', 'network_518.csv', 'network_509.csv', 'network_330.csv', 'network_316.csv', 'network_455.csv', 'network_494.csv', 'network_463.csv', 'network_721.csv', 'network_95.csv', 'network_739.csv', 'network_56.csv', 'network_154.csv', 'network_621.csv', 'network_661.csv', 'network_766.csv', 'network_608.csv', 'network_703.csv', 'network_488.csv', 'network_205.csv', 'network_487.csv', 'network_175.csv', 'network_670.csv', 'network_593.csv', 'network_291.csv', 'network_448.csv', 'network_57.csv', 'network_656.csv', 'network_514.csv', 'network_15.csv', 'network_61.csv', 'network_708.csv', 'network_50.csv', 'network_195.csv', 'network_279.csv', 'network_293.csv', 'network_251.csv', 'network_495.csv', 'network_775.csv', 'network_68.csv', 'network_768.csv', 'network_182.csv', 'network_717.csv', 'network_187.csv', 'network_322.csv', 'network_754.csv', 'network_718.csv', 'network_81.csv', 'network_148.csv', 'network_536.csv', 'network_477.csv', 'network_662.csv', 'network_260.csv', 'network_338.csv', 'network_644.csv', 'network_284.csv', 'network_441.csv', 'network_393.csv', 'network_378.csv', 'network_581.csv', 'network_502.csv', 'network_295.csv', 'network_344.csv', 'network_365.csv', 'network_210.csv', 'network_314.csv', 'network_172.csv', 'network_336.csv', 'network_761.csv', 'network_120.csv', 'network_323.csv', 'network_500.csv', 'network_665.csv', 'network_58.csv', 'network_698.csv', 'network_32.csv', 'network_270.csv', 'network_567.csv', 'network_168.csv', 'network_222.csv', 'network_144.csv', 'network_348.csv', 'network_531.csv', 'network_223.csv', 'network_425.csv', 'network_755.csv']
len(files)
# Out:
# 99

# %%
lis = [[0,0,0,1],[1,0,1],[1],[1,0]]


sumz = 0
for network in lis:
    for num in network:
        sumz+=
# Out:
#   Input In [2]
#     [for network in lis for num in network num==0]
#      ^
# SyntaxError: invalid syntax

# %%
perf =  ['network_67', 'network_12', 'network_90', 'network_50', 'network_6', 'network_85', 'network_69', 'network_63', 'network_35', 'network_31', 'network_119', 'network_13', 'network_71', 'network_14', 'network_59', 'network_91', 'network_30', 'network_86', 'network_195', 'network_172', 'network_154', 'network_175', 'network_125', 'network_46', 'network_37', 'network_97', 'network_62', 'network_76', 'network_26', 'network_25', 'network_160', 'network_82', 'network_146', 'network_45', 'network_164', 'network_192', 'network_187', 'network_182', 'network_126', 'network_18', 'network_17', 'network_191', 'network_179', 'network_61', 'network_176', 'network_197', 'network_137', 'network_55', 'network_60', 'network_180', 'network_141', 'network_4', 'network_127', 'network_171', 'network_1', 'network_161', 'network_169', 'network_53', 'network_143', 'network_147', 'network_162', 'network_33', 'network_106', 'network_116', 'network_140', 'network_184', 'network_101', 'network_21', 'network_52', 'network_41', 'network_118']
len(perf)
# Out:
# 71

# %%
broken_prev = ['network_7', 'network_166', 'network_44', 'network_11', 'network_165', 'network_65', 'network_70', 'network_36', 'network_9', 'network_159', 'network_2', 'network_135', 'network_80', 'network_77', 'network_167', 'network_103', 'network_34', 'network_134', 'network_122', 'network_68', 'network_57', 'network_170', 'network_96', 'network_113', 'network_186', 'network_29', 'network_163', 'network_190', 'network_15', 'network_49', 'network_109', 'network_112', 'network_10', 'network_133', 'network_102', 'network_47', 'network_58', 'network_177', 'network_79', 'network_130', 'network_185', 'network_99', 'network_193', 'network_73', 'network_84', 'network_8', 'network_121', 'network_56', 'network_142', 'network_22', 'network_144', 'network_136', 'network_120', 'network_43', 'network_54', 'network_152', 'network_111', 'network_72', 'network_27', 'network_81', 'network_153', 'network_189', 'network_110', 'network_39', 'network_196', 'network_105', 'network_28', 'network_83', 'network_75', 'network_48', 'network_138', 'network_174', 'network_132', 'network_40', 'network_117', 'network_194', 'network_128', 'network_188', 'network_129', 'network_151', 'network_115', 'network_150', 'network_24', 'network_74', 'network_5', 'network_173', 'network_157', 'network_158', 'network_123', 'network_51', 'network_198', 'network_16', 'network_23', 'network_139']
len(broken_prev)
# Out:
# 94

# %%
broken_new = ['network_157', 'network_27', 'network_36', 'network_28', 'network_68', 'network_16', 'network_24', 'network_193', 'network_34', 'network_57', 'network_133', 'network_96', 'network_150', 'network_74', 'network_44', 'network_158', 'network_120', 'network_40', 'network_110', 'network_43', 'network_138', 'network_132', 'network_166', 'network_188', 'network_54', 'network_130', 'network_8', 'network_65', 'network_185', 'network_142', 'network_29', 'network_123', 'network_84', 'network_48', 'network_99', 'network_190', 'network_49', 'network_115', 'network_9', 'network_117', 'network_58', 'network_113', 'network_10', 'network_70', 'network_75', 'network_56', 'network_144', 'network_47', 'network_80', 'network_174', 'network_165', 'network_167', 'network_136', 'network_77', 'network_139', 'network_134', 'network_5', 'network_103', 'network_73', 'network_196', 'network_189', 'network_122', 'network_23', 'network_128', 'network_121', 'network_135', 'network_72', 'network_83', 'network_170', 'network_7', 'network_186', 'network_81', 'network_152', 'network_51', 'network_177', 'network_159', 'network_153', 'network_11', 'network_198', 'network_151', 'network_105', 'network_112', 'network_111', 'network_15', 'network_39', 'network_102', 'network_163', 'network_109', 'network_173', 'network_79', 'network_22', 'network_2', 'network_194']
len(broken_new)
# Out:
# 93

# %%
set(broken_prev) - set(broken_new)
# Out:
# {'network_129'}

# %%
broken_final = ['network_185', 'network_36', 'network_48', 'network_188', 'network_153', 'network_79', 'network_39', 'network_2', 'network_68', 'network_99', 'network_117', 'network_163', 'network_81', 'network_10', 'network_194', 'network_34', 'network_122', 'network_83', 'network_8', 'network_29', 'network_22', 'network_70', 'network_54', 'network_7', 'network_120', 'network_167', 'network_130', 'network_47', 'network_112', 'network_9', 'network_5', 'network_198', 'network_102', 'network_103', 'network_139', 'network_177', 'network_136', 'network_109', 'network_73', 'network_75', 'network_170', 'network_58', 'network_84', 'network_57', 'network_186', 'network_196', 'network_128', 'network_16', 'network_150', 'network_151', 'network_152', 'network_40', 'network_24', 'network_44', 'network_111', 'network_173', 'network_74', 'network_77', 'network_165', 'network_159', 'network_28', 'network_96', 'network_43', 'network_27', 'network_190', 'network_11', 'network_80', 'network_158', 'network_144', 'network_121', 'network_193', 'network_189', 'network_166', 'network_65', 'network_15', 'network_49', 'network_123', 'network_51', 'network_134', 'network_56', 'network_138', 'network_72', 'network_23', 'network_132', 'network_110', 'network_133', 'network_135', 'network_174', 'network_142', 'network_115']
len(broken_final)
# Out:
# 90

# %%
perf = ['network_67', 'network_12', 'network_90', 'network_50', 'network_6', 'network_85', 'network_69', 'network_63', 'network_35', 'network_31', 'network_119', 'network_13', 'network_71', 'network_14', 'network_59', 'network_91', 'network_30', 'network_86', 'network_195', 'network_172', 'network_154', 'network_175', 'network_125', 'network_46', 'network_37', 'network_97', 'network_62', 'network_76', 'network_26', 'network_25', 'network_160', 'network_82', 'network_146', 'network_45', 'network_164', 'network_192', 'network_187', 'network_182', 'network_126', 'network_18', 'network_17', 'network_191', 'network_179', 'network_61', 'network_176', 'network_197', 'network_137', 'network_55', 'network_60', 'network_180', 'network_141', 'network_4', 'network_127', 'network_171', 'network_1', 'network_161', 'network_169', 'network_53', 'network_143', 'network_147', 'network_162', 'network_33', 'network_106', 'network_116', 'network_140', 'network_184', 'network_101', 'network_21', 'network_52', 'network_41', 'network_118']
len(perf)
# Out:
# 71

# %%
new_perf = ['network_85', 'network_78', 'network_8', 'network_73', 'network_3', 'network_57', 'network_22', 'network_88', 'network_33', 'network_47', 'network_13', 'network_43', 'network_10', 'network_1', 'network_41', 'network_9', 'network_23', 'network_52', 'network_37', 'network_15', 'network_4', 'network_72', 'network_77', 'network_51', 'network_63', 'network_86']
new_imperf = ['network_56', 'network_21', 'network_60', 'network_80', 'network_26', 'network_81', 'network_0', 'network_11', 'network_12', 'network_50', 'network_79', 'network_40', 'network_17', 'network_61', 'network_49', 'network_69', 'network_20', 'network_14', 'network_67', 'network_25', 'network_46', 'network_6']

# %%
len(new_imperf)
# Out:
# 22

# %%
sr_int = 50000
sr_bytes = sr_int.to_bytes(4, 'big')

# %%
sr_bytes
# Out:
# b'\x00\x00\xc3P'

# %%
broken_2x16x16_125000 = ['network_20_set_0', 'network_9_set_0', 'network_70_set_0', 'network_155_set_0', 'network_143_set_0', 'network_134_set_0', 'network_36_set_0', 'network_102_set_0', 'network_135_set_0', 'network_65_set_0', 'network_118_set_0', 'network_66_set_0', 'network_125_set_0', 'network_170_set_0', 'network_78_set_0', 'network_115_set_0', 'network_182_set_0', 'network_178_set_0', 'network_160_set_0', 'network_101_set_0', 'network_129_set_0', 'network_157_set_0', 'network_52_set_0', 'network_59_set_0', 'network_54_set_0', 'network_16_set_0', 'network_76_set_0', 'network_185_set_0', 'network_174_set_0', 'network_131_set_0', 'network_3_set_0', 'network_189_set_0', 'network_177_set_0', 'network_12_set_0', 'network_26_set_0', 'network_168_set_0', 'network_42_set_0', 'network_10_set_0', 'network_8_set_0', 'network_120_set_0', 'network_108_set_0', 'network_1_set_0']

len(broken_2x16x16_125000)
# Out:
# 42

# %%
broken_2x16x16_175000 = ['network_38_set_0', 'network_164_set_0', 'network_113_set_0', 'network_188_set_0', 'network_139_set_0', 'network_114_set_0', 'network_154_set_0', 'network_120_set_0', 'network_4_set_0', 'network_118_set_0', 'network_9_set_0', 'network_16_set_0', 'network_143_set_0', 'network_152_set_0', 'network_55_set_0', 'network_141_set_0', 'network_56_set_0', 'network_193_set_0', 'network_26_set_0', 'network_79_set_0', 'network_69_set_0', 'network_137_set_0', 'network_75_set_0', 'network_125_set_0', 'network_82_set_0', 'network_48_set_0', 'network_42_set_0', 'network_70_set_0', 'network_190_set_0', 'network_106_set_0', 'network_36_set_0', 'network_83_set_0', 'network_100_set_0', 'network_65_set_0', 'network_171_set_0', 'network_179_set_0', 'network_12_set_0', 'network_99_set_0', 'network_81_set_0', 'network_140_set_0', 'network_6_set_0', 'network_167_set_0', 'network_29_set_0', 'network_3_set_0', 'network_60_set_0', 'network_31_set_0', 'network_149_set_0', 'network_169_set_0', 'network_47_set_0', 'network_157_set_0', 'network_2_set_0', 'network_153_set_0', 'network_134_set_0', 'network_13_set_0', 'network_52_set_0', 'network_46_set_0', 'network_7_set_0']
len(broken_2x16x16_175000)
# Out:
# 57

# %%
broken_2x16x16_525k = ['network_171_set_0', 'network_191_set_0', 'network_111_set_0', 'network_2_set_0', 'network_35_set_0', 'network_52_set_0', 'network_110_set_0', 'network_89_set_0', 'network_47_set_0', 'network_116_set_0', 'network_15_set_0', 'network_172_set_0', 'network_14_set_0', 'network_178_set_0', 'network_133_set_0', 'network_83_set_0', 'network_30_set_0', 'network_55_set_0', 'network_151_set_0', 'network_81_set_0', 'network_51_set_0', 'network_170_set_0', 'network_46_set_0', 'network_139_set_0', 'network_101_set_0', 'network_195_set_0', 'network_18_set_0', 'network_197_set_0', 'network_130_set_0', 'network_62_set_0', 'network_4_set_0', 'network_148_set_0', 'network_136_set_0', 'network_44_set_0', 'network_179_set_0', 'network_102_set_0', 'network_56_set_0', 'network_185_set_0', 'network_21_set_0', 'network_176_set_0', 'network_7_set_0', 'network_84_set_0', 'network_1_set_0', 'network_193_set_0', 'network_149_set_0', 'network_72_set_0', 'network_70_set_0', 'network_126_set_0', 'network_26_set_0', 'network_183_set_0', 'network_65_set_0', 'network_108_set_0', 'network_152_set_0', 'network_24_set_0', 'network_8_set_0', 'network_54_set_0', 'network_186_set_0', 'network_181_set_0', 'network_194_set_0', 'network_175_set_0', 'network_43_set_0', 'network_73_set_0', 'network_50_set_0', 'network_106_set_0', 'network_104_set_0', 'network_78_set_0', 'network_96_set_0', 'network_57_set_0']
len(broken_2x16x16_525k)
# Out:
# 68

# %%
broken_2x16x16_350 = ['network_125_set_0', 'network_177_set_0', 'network_172_set_0', 'network_21_set_0', 'network_129_set_0', 'network_160_set_0', 'network_128_set_0', 'network_114_set_0', 'network_182_set_0', 'network_149_set_0', 'network_153_set_0', 'network_151_set_0', 'network_87_set_0', 'network_91_set_0', 'network_57_set_0', 'network_70_set_0', 'network_120_set_0', 'network_55_set_0', 'network_44_set_0', 'network_13_set_0', 'network_133_set_0', 'network_113_set_0', 'network_37_set_0', 'network_158_set_0', 'network_38_set_0', 'network_108_set_0', 'network_193_set_0', 'network_198_set_0', 'network_163_set_0', 'network_32_set_0', 'network_28_set_0', 'network_94_set_0', 'network_105_set_0', 'network_14_set_0', 'network_82_set_0', 'network_29_set_0', 'network_35_set_0', 'network_48_set_0', 'network_102_set_0', 'network_196_set_0', 'network_171_set_0', 'network_155_set_0', 'network_6_set_0', 'network_30_set_0', 'network_67_set_0', 'network_78_set_0', 'network_121_set_0', 'network_64_set_0', 'network_103_set_0', 'network_104_set_0', 'network_31_set_0', 'network_189_set_0', 'network_122_set_0', 'network_119_set_0', 'network_123_set_0', 'network_2_set_0', 'network_92_set_0', 'network_40_set_0', 'network_79_set_0', 'network_60_set_0', 'network_58_set_0', 'network_165_set_0', 'network_180_set_0', 'network_98_set_0', 'network_47_set_0', 'network_74_set_0', 'network_20_set_0', 'network_106_set_0', 'network_27_set_0', 'network_49_set_0', 'network_115_set_0', 'network_61_set_0', 'network_118_set_0', 'network_97_set_0', 'network_33_set_0', 'network_162_set_0', 'network_51_set_0', 'network_19_set_0', 'network_54_set_0', 'network_80_set_0', 'network_176_set_0', 'network_146_set_0', 'network_63_set_0', 'network_86_set_0', 'network_136_set_0']
len(broken_2x16x16_350)
# Out:
# 85

# %%
broken_300k = ['network_161_set_0', 'network_24_set_0', 'network_44_set_0', 'network_149_set_0', 'network_171_set_0', 'network_125_set_0', 'network_40_set_0', 'network_165_set_0', 'network_188_set_0', 'network_5_set_0', 'network_31_set_0', 'network_4_set_0', 'network_87_set_0', 'network_170_set_0', 'network_154_set_0', 'network_160_set_0', 'network_126_set_0', 'network_199_set_0', 'network_153_set_0', 'network_19_set_0', 'network_135_set_0', 'network_173_set_0', 'network_15_set_0', 'network_194_set_0', 'network_166_set_0', 'network_42_set_0', 'network_48_set_0', 'network_11_set_0', 'network_67_set_0', 'network_158_set_0', 'network_30_set_0', 'network_58_set_0', 'network_26_set_0', 'network_81_set_0', 'network_196_set_0', 'network_123_set_0', 'network_144_set_0', 'network_110_set_0', 'network_52_set_0', 'network_60_set_0', 'network_168_set_0', 'network_62_set_0', 'network_98_set_0', 'network_28_set_0', 'network_176_set_0', 'network_53_set_0', 'network_175_set_0', 'network_82_set_0', 'network_177_set_0', 'network_140_set_0', 'network_9_set_0', 'network_6_set_0', 'network_102_set_0', 'network_21_set_0', 'network_51_set_0', 'network_13_set_0', 'network_155_set_0', 'network_75_set_0', 'network_14_set_0', 'network_178_set_0', 'network_3_set_0', 'network_141_set_0', 'network_119_set_0', 'network_22_set_0', 'network_71_set_0', 'network_117_set_0', 'network_198_set_0', 'network_23_set_0', 'network_169_set_0', 'network_118_set_0', 'network_146_set_0', 'network_164_set_0', 'network_181_set_0', 'network_25_set_0', 'network_103_set_0', 'network_27_set_0']
len(broken_300k)
# Out:
# 76

# %%
broken_125k = ['network_84_set_0', 'network_45_set_0', 'network_175_set_0', 'network_125_set_0', 'network_4_set_0', 'network_167_set_0', 'network_99_set_0', 'network_78_set_0', 'network_98_set_0', 'network_160_set_0', 'network_50_set_0', 'network_65_set_0', 'network_35_set_0', 'network_106_set_0', 'network_116_set_0', 'network_147_set_0', 'network_143_set_0', 'network_154_set_0', 'network_64_set_0', 'network_155_set_0', 'network_159_set_0', 'network_195_set_0', 'network_7_set_0', 'network_49_set_0', 'network_13_set_0', 'network_152_set_0', 'network_131_set_0', 'network_51_set_0', 'network_187_set_0', 'network_119_set_0', 'network_66_set_0', 'network_32_set_0', 'network_166_set_0', 'network_92_set_0', 'network_138_set_0', 'network_30_set_0', 'network_142_set_0', 'network_139_set_0', 'network_11_set_0', 'network_93_set_0', 'network_184_set_0']
len(broken_125k)
# Out:
# 41

# %%
broken_100k = ['network_70_set_0', 'network_41_set_0', 'network_197_set_0', 'network_26_set_0', 'network_162_set_0', 'network_105_set_0', 'network_160_set_0', 'network_166_set_0', 'network_12_set_0', 'network_189_set_0', 'network_56_set_0', 'network_145_set_0', 'network_115_set_0', 'network_111_set_0', 'network_193_set_0', 'network_2_set_0', 'network_138_set_0', 'network_29_set_0', 'network_144_set_0', 'network_194_set_0', 'network_129_set_0', 'network_195_set_0', 'network_198_set_0', 'network_178_set_0', 'network_73_set_0', 'network_14_set_0', 'network_159_set_0', 'network_44_set_0', 'network_185_set_0', 'network_64_set_0', 'network_36_set_0', 'network_184_set_0', 'network_199_set_0', 'network_108_set_0', 'network_99_set_0', 'network_126_set_0', 'network_80_set_0', 'network_40_set_0', 'network_157_set_0', 'network_196_set_0', 'network_124_set_0', 'network_170_set_0', 'network_4_set_0', 'network_148_set_0', 'network_88_set_0', 'network_119_set_0', 'network_183_set_0', 'network_102_set_0', 'network_101_set_0']
len(broken_100k)
# Out:
# 49

# %%
perf = ['network_12_set_1', 'network_142_set_2', 'network_33_set_2', 'network_148_set_2', 'network_0_set_0', 'network_170_set_2', 'network_14_set_1', 'network_9_set_0', 'network_187_set_2', 'network_184_set_2', 'network_88_set_2', 'network_17_set_2', 'network_180_set_2', 'network_112_set_2', 'network_97_set_1', 'network_62_set_1', 'network_63_set_2', 'network_7_set_0', 'network_150_set_2', 'network_72_set_1', 'network_21_set_2', 'network_1_set_1', 'network_77_set_1', 'network_24_set_2', 'network_94_set_2', 'network_73_set_2', 'network_20_set_2', 'network_3_set_1', 'network_105_set_2', 'network_32_set_1', 'network_15_set_1', 'network_96_set_2', 'network_9_set_2', 'network_49_set_1', 'network_40_set_2', 'network_123_set_1', 'network_23_set_1', 'network_18_set_1', 'network_52_set_2', 'network_7_set_2', 'network_7_set_1', 'network_121_set_2', 'network_152_set_2', 'network_25_set_2', 'network_95_set_2', 'network_84_set_2', 'network_13_set_0', 'network_179_set_2', 'network_12_set_0', 'network_126_set_2', 'network_138_set_2', 'network_173_set_2', 'network_174_set_2', 'network_100_set_2', 'network_122_set_1', 'network_95_set_1', 'network_55_set_1', 'network_129_set_2', 'network_71_set_2', 'network_41_set_1', 'network_29_set_1', 'network_107_set_1', 'network_0_set_2', 'network_10_set_2', 'network_6_set_1', 'network_26_set_2', 'network_57_set_2', 'network_21_set_1', 'network_66_set_2', 'network_63_set_1', 'network_86_set_1', 'network_186_set_2', 'network_85_set_1', 'network_27_set_2', 'network_144_set_2', 'network_104_set_1', 'network_93_set_1', 'network_120_set_2', 'network_22_set_0', 'network_22_set_1', 'network_107_set_2', 'network_51_set_1', 'network_78_set_2', 'network_106_set_2', 'network_130_set_2', 'network_24_set_0', 'network_22_set_2', 'network_121_set_1', 'network_31_set_1', 'network_16_set_2', 'network_34_set_2', 'network_59_set_2', 'network_38_set_1', 'network_37_set_1', 'network_65_set_1', 'network_30_set_2', 'network_14_set_2', 'network_124_set_1', 'network_55_set_2', 'network_102_set_1', 'network_109_set_1', 'network_80_set_1', 'network_93_set_2', 'network_45_set_2', 'network_149_set_2', 'network_151_set_2', 'network_141_set_2', 'network_128_set_2', 'network_167_set_2', 'network_132_set_2', 'network_4_set_2', 'network_53_set_2', 'network_108_set_1', 'network_53_set_1', 'network_113_set_1', 'network_157_set_2', 'network_12_set_2', 'network_42_set_2', 'network_191_set_2', 'network_18_set_2', 'network_67_set_2', 'network_135_set_2', 'network_108_set_2', 'network_48_set_1', 'network_43_set_2', 'network_96_set_1', 'network_18_set_0', 'network_99_set_1', 'network_84_set_1', 'network_194_set_2', 'network_87_set_1', 'network_189_set_2', 'network_146_set_2', 'network_2_set_0', 'network_110_set_1', 'network_161_set_2', 'network_21_set_0', 'network_44_set_1', 'network_8_set_2', 'network_171_set_2', 'network_45_set_1', 'network_77_set_2', 'network_46_set_2', 'network_28_set_0', 'network_181_set_2', 'network_127_set_1', 'network_139_set_2', 'network_15_set_2', 'network_8_set_1', 'network_100_set_1', 'network_123_set_2', 'network_94_set_1', 'network_156_set_2', 'network_58_set_2', 'network_131_set_2', 'network_113_set_2', 'network_103_set_2', 'network_92_set_1', 'network_137_set_2', 'network_83_set_1', 'network_23_set_2', 'network_192_set_2', 'network_82_set_1', 'network_34_set_1', 'network_37_set_2', 'network_56_set_1', 'network_68_set_2', 'network_11_set_0', 'network_175_set_2', 'network_80_set_2', 'network_133_set_2', 'network_72_set_2', 'network_57_set_1', 'network_6_set_2', 'network_114_set_2', 'network_8_set_0', 'network_40_set_1', 'network_10_set_0', 'network_91_set_2', 'network_155_set_2', 'network_153_set_2', 'network_159_set_2', 'network_5_set_1', 'network_0_set_1', 'network_46_set_1', 'network_31_set_2', 'network_35_set_2', 'network_54_set_2', 'network_75_set_2', 'network_82_set_2', 'network_58_set_1', 'network_160_set_2', 'network_164_set_2', 'network_136_set_2', 'network_126_set_1', 'network_56_set_2', 'network_145_set_2', 'network_24_set_1', 'network_29_set_2', 'network_119_set_1', 'network_17_set_0', 'network_4_set_1', 'network_1_set_2', 'network_28_set_1', 'network_9_set_1', 'network_154_set_2', 'network_30_set_1', 'network_76_set_1', 'network_42_set_1', 'network_124_set_2', 'network_92_set_2', 'network_190_set_2', 'network_122_set_2', 'network_127_set_2', 'network_23_set_0', 'network_165_set_2', 'network_110_set_2', 'network_163_set_2', 'network_50_set_2', 'network_1_set_0', 'network_65_set_2', 'network_109_set_2', 'network_25_set_0', 'network_51_set_2', 'network_118_set_2', 'network_73_set_1', 'network_60_set_2', 'network_98_set_1', 'network_106_set_1', 'network_188_set_2', 'network_162_set_2', 'network_39_set_2', 'network_70_set_2', 'network_71_set_1', 'network_169_set_2', 'network_20_set_0', 'network_140_set_2', 'network_101_set_1', 'network_19_set_0', 'network_44_set_2', 'network_35_set_1', 'network_48_set_2', 'network_50_set_1', 'network_111_set_1', 'network_81_set_2', 'network_176_set_2', 'network_74_set_2', 'network_114_set_1', 'network_87_set_2', 'network_102_set_2', 'network_172_set_2', 'network_27_set_1', 'network_105_set_1', 'network_104_set_2', 'network_52_set_1', 'network_49_set_2', 'network_69_set_2', 'network_19_set_2', 'network_86_set_2', 'network_183_set_2', 'network_26_set_0', 'network_147_set_2', 'network_101_set_2', 'network_119_set_2', 'network_62_set_2', 'network_89_set_2', 'network_128_set_1', 'network_125_set_2', 'network_2_set_2', 'network_66_set_1']
len(perf)
# Out:
# 270

# %%
print('#[version = "0.0.5"]\ndef @main(%input0: Tensor[(1, 3, 224, 224), float32]) -> Tensor[(1, 10), float32] {\n  %0 = nn.conv2d(%input0, meta[relay.Constant][0] /* ty=Tensor[(32, 3, 7, 7), float32] */, strides=[2, 2], padding=[3, 3, 3, 3], channels=32, kernel_size=[7, 7]) /* ty=Tensor[(1, 32, 112, 112), float32] */;\n  %1 = add(%0, meta[relay.Constant][1] /* ty=Tensor[(32, 1, 1), float32] */) /* ty=Tensor[(1, 32, 112, 112), float32] */;\n  %2 = nn.relu(%1) /* ty=Tensor[(1, 32, 112, 112), float32] */;\n  %3 = nn.max_pool2d(%2, pool_size=[2, 2], strides=[2, 2], padding=[0, 0, 0, 0]) /* ty=Tensor[(1, 32, 56, 56), float32] */;\n  %4 = annotation.stop_fusion(%3) /* ty=Tensor[(1, 32, 56, 56), float32] */;\n  %5 = strided_slice(%4, begin=[0, 0, 0, 0], end=[1, 8, 56, 56], strides=[1, 1, 1, 1], axes=None) /* ty=Tensor[(1, 8, 56, 56), float32] */;\n  %6 = multiply(%5, 16f /* ty=float32 */) /* ty=Tensor[(1, 8, 56, 56), float32] */;\n  %7 = round(%6) /* ty=Tensor[(1, 8, 56, 56), float32] */;\n  %8 = clip(%7, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 56, 56), float32] */;\n  %9 = cast(%8, dtype="int8") /* ty=Tensor[(1, 8, 56, 56), int8] */;\n  %10 = nn.conv2d(%9, meta[relay.Constant][2] /* ty=Tensor[(32, 8, 3, 3), int8] */, padding=[1, 1, 1, 1], channels=32, kernel_size=[3, 3], out_dtype="int32") /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %11 = add(%10, 512 /* ty=int32 */) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %12 = right_shift(%11, 10 /* ty=int32 */) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %13 = clip(%12, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %14 = cast(%13, dtype="int8") /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %15 = annotation.stop_fusion(%14) /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %16 = cast(%15, dtype="int32") /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %17 = strided_slice(%4, begin=[0, 8, 0, 0], end=[1, 16, 56, 56], strides=[1, 1, 1, 1], axes=None) /* ty=Tensor[(1, 8, 56, 56), float32] */;\n  %18 = multiply(%17, 16f /* ty=float32 */) /* ty=Tensor[(1, 8, 56, 56), float32] */;\n  %19 = round(%18) /* ty=Tensor[(1, 8, 56, 56), float32] */;\n  %20 = clip(%19, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 56, 56), float32] */;\n  %21 = cast(%20, dtype="int8") /* ty=Tensor[(1, 8, 56, 56), int8] */;\n  %22 = nn.conv2d(%21, meta[relay.Constant][3] /* ty=Tensor[(32, 8, 3, 3), int8] */, padding=[1, 1, 1, 1], channels=32, kernel_size=[3, 3], out_dtype="int32") /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %23 = add(%22, 256 /* ty=int32 */) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %24 = right_shift(%23, 9 /* ty=int32 */) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %25 = clip(%24, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %26 = cast(%25, dtype="int8") /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %27 = annotation.stop_fusion(%26) /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %28 = cast(%27, dtype="int32") /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %29 = add(%16, %28) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %30 = cast(%29, dtype="int8") /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %31 = annotation.stop_fusion(%30) /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %32 = cast(%31, dtype="int32") /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %33 = strided_slice(%4, begin=[0, 16, 0, 0], end=[1, 24, 56, 56], strides=[1, 1, 1, 1], axes=None) /* ty=Tensor[(1, 8, 56, 56), float32] */;\n  %34 = multiply(%33, 16f /* ty=float32 */) /* ty=Tensor[(1, 8, 56, 56), float32] */;\n  %35 = round(%34) /* ty=Tensor[(1, 8, 56, 56), float32] */;\n  %36 = clip(%35, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 56, 56), float32] */;\n  %37 = cast(%36, dtype="int8") /* ty=Tensor[(1, 8, 56, 56), int8] */;\n  %38 = nn.conv2d(%37, meta[relay.Constant][4] /* ty=Tensor[(32, 8, 3, 3), int8] */, padding=[1, 1, 1, 1], channels=32, kernel_size=[3, 3], out_dtype="int32") /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %39 = add(%38, 256 /* ty=int32 */) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %40 = right_shift(%39, 9 /* ty=int32 */) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %41 = clip(%40, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %42 = cast(%41, dtype="int8") /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %43 = annotation.stop_fusion(%42) /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %44 = cast(%43, dtype="int32") /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %45 = add(%32, %44) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %46 = cast(%45, dtype="int8") /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %47 = annotation.stop_fusion(%46) /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %48 = cast(%47, dtype="int32") /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %49 = strided_slice(%4, begin=[0, 24, 0, 0], end=[1, 32, 56, 56], strides=[1, 1, 1, 1], axes=None) /* ty=Tensor[(1, 8, 56, 56), float32] */;\n  %50 = multiply(%49, 16f /* ty=float32 */) /* ty=Tensor[(1, 8, 56, 56), float32] */;\n  %51 = round(%50) /* ty=Tensor[(1, 8, 56, 56), float32] */;\n  %52 = clip(%51, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 56, 56), float32] */;\n  %53 = cast(%52, dtype="int8") /* ty=Tensor[(1, 8, 56, 56), int8] */;\n  %54 = nn.conv2d(%53, meta[relay.Constant][5] /* ty=Tensor[(32, 8, 3, 3), int8] */, padding=[1, 1, 1, 1], channels=32, kernel_size=[3, 3], out_dtype="int32") /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %55 = add(%54, 512 /* ty=int32 */) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %56 = right_shift(%55, 10 /* ty=int32 */) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %57 = clip(%56, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %58 = cast(%57, dtype="int8") /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %59 = annotation.stop_fusion(%58) /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %60 = cast(%59, dtype="int32") /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %61 = add(%48, %60) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %62 = left_shift(%61, 2 /* ty=int32 */) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %63 = add(%62, meta[relay.Constant][6] /* ty=Tensor[(32, 1, 1), int32] */) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %64 = add(%63, 2 /* ty=int32 */) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %65 = right_shift(%64, 2 /* ty=int32 */) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %66 = clip(%65, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %67 = cast(%66, dtype="int8") /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %68 = annotation.stop_fusion(%67) /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %69 = cast(%68, dtype="int32") /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %70 = annotation.stop_fusion(%3) /* ty=Tensor[(1, 32, 56, 56), float32] */;\n  %71 = multiply(%70, 16f /* ty=float32 */) /* ty=Tensor[(1, 32, 56, 56), float32] */;\n  %72 = round(%71) /* ty=Tensor[(1, 32, 56, 56), float32] */;\n  %73 = clip(%72, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 56, 56), float32] */;\n  %74 = cast(%73, dtype="int32") /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %75 = annotation.stop_fusion(%74) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %76 = add(%69, %75) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %77 = nn.relu(%76) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %78 = clip(%77, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %79 = cast(%78, dtype="int8") /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %80 = annotation.stop_fusion(%79) /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %81 = nn.conv2d(%80, meta[relay.Constant][7] /* ty=Tensor[(32, 32, 5, 5), int8] */, padding=[2, 2, 2, 2], channels=32, kernel_size=[5, 5], out_dtype="int32") /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %82 = add(%81, meta[relay.Constant][8] /* ty=Tensor[(32, 1, 1), int32] */) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %83 = add(%82, 1024 /* ty=int32 */) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %84 = right_shift(%83, 11 /* ty=int32 */) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %85 = clip(%84, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %86 = cast(%85, dtype="int8") /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %87 = annotation.stop_fusion(%86) /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %88 = cast(%87, dtype="int32") /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %89 = cast(%78, dtype="int8") /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %90 = annotation.stop_fusion(%89) /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %91 = cast(%90, dtype="int32") /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %92 = add(%88, %91) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %93 = nn.relu(%92) /* ty=Tensor[(1, 32, 56, 56), int32] */;\n  %94 = cast(%93, dtype="int8") /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %95 = annotation.stop_fusion(%94) /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %96 = clip(%95, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 56, 56), int8] */;\n  %97 = strided_slice(%96, begin=[0, 0, 0, 0], end=[1, 8, 56, 56], strides=[1, 1, 1, 1], axes=None) /* ty=Tensor[(1, 8, 56, 56), int8] */;\n  %98 = nn.conv2d(%97, meta[relay.Constant][9] /* ty=Tensor[(128, 8, 3, 3), int8] */, strides=[2, 2], padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3], out_dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %99 = add(%98, 512 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %100 = right_shift(%99, 10 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %101 = clip(%100, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %102 = cast(%101, dtype="int8") /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %103 = annotation.stop_fusion(%102) /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %104 = cast(%103, dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %105 = strided_slice(%96, begin=[0, 8, 0, 0], end=[1, 16, 56, 56], strides=[1, 1, 1, 1], axes=None) /* ty=Tensor[(1, 8, 56, 56), int8] */;\n  %106 = nn.conv2d(%105, meta[relay.Constant][10] /* ty=Tensor[(128, 8, 3, 3), int8] */, strides=[2, 2], padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3], out_dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %107 = add(%106, 512 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %108 = right_shift(%107, 10 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %109 = clip(%108, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %110 = cast(%109, dtype="int8") /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %111 = annotation.stop_fusion(%110) /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %112 = cast(%111, dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %113 = add(%104, %112) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %114 = cast(%113, dtype="int8") /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %115 = annotation.stop_fusion(%114) /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %116 = cast(%115, dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %117 = strided_slice(%96, begin=[0, 16, 0, 0], end=[1, 24, 56, 56], strides=[1, 1, 1, 1], axes=None) /* ty=Tensor[(1, 8, 56, 56), int8] */;\n  %118 = nn.conv2d(%117, meta[relay.Constant][11] /* ty=Tensor[(128, 8, 3, 3), int8] */, strides=[2, 2], padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3], out_dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %119 = add(%118, 256 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %120 = right_shift(%119, 9 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %121 = clip(%120, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %122 = cast(%121, dtype="int8") /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %123 = annotation.stop_fusion(%122) /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %124 = cast(%123, dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %125 = add(%116, %124) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %126 = cast(%125, dtype="int8") /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %127 = annotation.stop_fusion(%126) /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %128 = cast(%127, dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %129 = strided_slice(%96, begin=[0, 24, 0, 0], end=[1, 32, 56, 56], strides=[1, 1, 1, 1], axes=None) /* ty=Tensor[(1, 8, 56, 56), int8] */;\n  %130 = nn.conv2d(%129, meta[relay.Constant][12] /* ty=Tensor[(128, 8, 3, 3), int8] */, strides=[2, 2], padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3], out_dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %131 = add(%130, 512 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %132 = right_shift(%131, 10 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %133 = clip(%132, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %134 = cast(%133, dtype="int8") /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %135 = annotation.stop_fusion(%134) /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %136 = cast(%135, dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %137 = add(%128, %136) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %138 = left_shift(%137, 1 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %139 = add(%138, meta[relay.Constant][13] /* ty=Tensor[(128, 1, 1), int32] */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %140 = add(%139, 1 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %141 = right_shift(%140, 1 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %142 = clip(%141, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %143 = cast(%142, dtype="int8") /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %144 = annotation.stop_fusion(%143) /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %145 = cast(%144, dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %146 = strided_slice(%96, begin=[0, 0, 0, 0], end=[1, 8, 56, 56], strides=[1, 1, 1, 1], axes=None) /* ty=Tensor[(1, 8, 56, 56), int8] */;\n  %147 = nn.conv2d(%146, meta[relay.Constant][14] /* ty=Tensor[(128, 8, 1, 1), int8] */, strides=[2, 2], padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1], out_dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %148 = add(%147, 128 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %149 = right_shift(%148, 8 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %150 = clip(%149, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %151 = cast(%150, dtype="int8") /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %152 = annotation.stop_fusion(%151) /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %153 = cast(%152, dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %154 = strided_slice(%96, begin=[0, 8, 0, 0], end=[1, 16, 56, 56], strides=[1, 1, 1, 1], axes=None) /* ty=Tensor[(1, 8, 56, 56), int8] */;\n  %155 = nn.conv2d(%154, meta[relay.Constant][15] /* ty=Tensor[(128, 8, 1, 1), int8] */, strides=[2, 2], padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1], out_dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %156 = add(%155, 128 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %157 = right_shift(%156, 8 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %158 = clip(%157, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %159 = cast(%158, dtype="int8") /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %160 = annotation.stop_fusion(%159) /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %161 = cast(%160, dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %162 = add(%153, %161) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %163 = cast(%162, dtype="int8") /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %164 = annotation.stop_fusion(%163) /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %165 = cast(%164, dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %166 = strided_slice(%96, begin=[0, 16, 0, 0], end=[1, 24, 56, 56], strides=[1, 1, 1, 1], axes=None) /* ty=Tensor[(1, 8, 56, 56), int8] */;\n  %167 = nn.conv2d(%166, meta[relay.Constant][16] /* ty=Tensor[(128, 8, 1, 1), int8] */, strides=[2, 2], padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1], out_dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %168 = add(%167, 128 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %169 = right_shift(%168, 8 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %170 = clip(%169, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %171 = cast(%170, dtype="int8") /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %172 = annotation.stop_fusion(%171) /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %173 = cast(%172, dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %174 = add(%165, %173) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %175 = cast(%174, dtype="int8") /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %176 = annotation.stop_fusion(%175) /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %177 = cast(%176, dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %178 = strided_slice(%96, begin=[0, 24, 0, 0], end=[1, 32, 56, 56], strides=[1, 1, 1, 1], axes=None) /* ty=Tensor[(1, 8, 56, 56), int8] */;\n  %179 = nn.conv2d(%178, meta[relay.Constant][17] /* ty=Tensor[(128, 8, 1, 1), int8] */, strides=[2, 2], padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1], out_dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %180 = add(%179, 64 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %181 = right_shift(%180, 7 /* ty=int32 */) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %182 = clip(%181, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %183 = cast(%182, dtype="int8") /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %184 = annotation.stop_fusion(%183) /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %185 = cast(%184, dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %186 = add(%177, %185) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %187 = cast(%186, dtype="int8") /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %188 = annotation.stop_fusion(%187) /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %189 = cast(%188, dtype="int32") /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %190 = add(%145, %189) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %191 = nn.relu(%190) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %192 = clip(%191, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 28, 28), int32] */;\n  %193 = cast(%192, dtype="int8") /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %194 = annotation.stop_fusion(%193) /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %195 = nn.conv2d(%194, meta[relay.Constant][18] /* ty=Tensor[(256, 128, 3, 3), int8] */, strides=[2, 2], padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3], out_dtype="int32") /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %196 = add(%195, meta[relay.Constant][19] /* ty=Tensor[(256, 1, 1), int32] */) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %197 = add(%196, 256 /* ty=int32 */) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %198 = right_shift(%197, 9 /* ty=int32 */) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %199 = clip(%198, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %200 = cast(%199, dtype="int8") /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %201 = annotation.stop_fusion(%200) /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %202 = cast(%201, dtype="int32") /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %203 = cast(%192, dtype="int8") /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %204 = annotation.stop_fusion(%203) /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %205 = clip(%204, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 128, 28, 28), int8] */;\n  %206 = strided_slice(%205, begin=[0, 0, 0, 0], end=[1, 64, 28, 28], strides=[1, 1, 1, 1], axes=None) /* ty=Tensor[(1, 64, 28, 28), int8] */;\n  %207 = nn.conv2d(%206, meta[relay.Constant][20] /* ty=Tensor[(256, 64, 1, 1), int8] */, strides=[2, 2], padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1], out_dtype="int32") /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %208 = add(%207, 64 /* ty=int32 */) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %209 = right_shift(%208, 7 /* ty=int32 */) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %210 = clip(%209, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %211 = cast(%210, dtype="int8") /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %212 = annotation.stop_fusion(%211) /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %213 = cast(%212, dtype="int32") /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %214 = strided_slice(%205, begin=[0, 64, 0, 0], end=[1, 128, 28, 28], strides=[1, 1, 1, 1], axes=None) /* ty=Tensor[(1, 64, 28, 28), int8] */;\n  %215 = nn.conv2d(%214, meta[relay.Constant][21] /* ty=Tensor[(256, 64, 1, 1), int8] */, strides=[2, 2], padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1], out_dtype="int32") /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %216 = add(%215, 64 /* ty=int32 */) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %217 = right_shift(%216, 7 /* ty=int32 */) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %218 = clip(%217, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %219 = cast(%218, dtype="int8") /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %220 = annotation.stop_fusion(%219) /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %221 = cast(%220, dtype="int32") /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %222 = add(%213, %221) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %223 = cast(%222, dtype="int8") /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %224 = annotation.stop_fusion(%223) /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %225 = cast(%224, dtype="int32") /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %226 = add(%202, %225) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %227 = nn.relu(%226) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %228 = clip(%227, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %229 = cast(%228, dtype="int8") /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %230 = annotation.stop_fusion(%229) /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %231 = nn.conv2d(%230, meta[relay.Constant][22] /* ty=Tensor[(256, 256, 3, 3), int8] */, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3], out_dtype="int32") /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %232 = add(%231, meta[relay.Constant][23] /* ty=Tensor[(256, 1, 1), int32] */) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %233 = add(%232, 512 /* ty=int32 */) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %234 = right_shift(%233, 10 /* ty=int32 */) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %235 = clip(%234, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %236 = cast(%235, dtype="int8") /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %237 = annotation.stop_fusion(%236) /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %238 = cast(%237, dtype="int32") /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %239 = cast(%228, dtype="int8") /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %240 = annotation.stop_fusion(%239) /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %241 = cast(%240, dtype="int32") /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %242 = add(%238, %241) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %243 = nn.relu(%242) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %244 = clip(%243, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 256, 14, 14), int32] */;\n  %245 = cast(%244, dtype="int8") /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %246 = annotation.stop_fusion(%245) /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %247 = nn.conv2d(%246, meta[relay.Constant][24] /* ty=Tensor[(1024, 256, 5, 5), int8] */, strides=[2, 2], padding=[2, 2, 2, 2], channels=1024, kernel_size=[5, 5], out_dtype="int32") /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %248 = add(%247, meta[relay.Constant][25] /* ty=Tensor[(1024, 1, 1), int32] */) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %249 = nn.relu(%248) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %250 = add(%249, 512 /* ty=int32 */) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %251 = right_shift(%250, 10 /* ty=int32 */) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %252 = clip(%251, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %253 = cast(%252, dtype="int8") /* ty=Tensor[(1, 1024, 7, 7), int8] */;\n  %254 = annotation.stop_fusion(%253) /* ty=Tensor[(1, 1024, 7, 7), int8] */;\n  %255 = nn.conv2d(%254, meta[relay.Constant][26] /* ty=Tensor[(1024, 1024, 7, 7), int8] */, padding=[3, 3, 3, 3], channels=1024, kernel_size=[7, 7], out_dtype="int32") /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %256 = add(%255, meta[relay.Constant][27] /* ty=Tensor[(1024, 1, 1), int32] */) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %257 = add(%256, 1024 /* ty=int32 */) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %258 = right_shift(%257, 11 /* ty=int32 */) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %259 = clip(%258, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %260 = cast(%259, dtype="int8") /* ty=Tensor[(1, 1024, 7, 7), int8] */;\n  %261 = annotation.stop_fusion(%260) /* ty=Tensor[(1, 1024, 7, 7), int8] */;\n  %262 = cast(%261, dtype="int32") /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %263 = cast(%244, dtype="int8") /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %264 = annotation.stop_fusion(%263) /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %265 = clip(%264, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 256, 14, 14), int8] */;\n  %266 = strided_slice(%265, begin=[0, 0, 0, 0], end=[1, 128, 14, 14], strides=[1, 1, 1, 1], axes=None) /* ty=Tensor[(1, 128, 14, 14), int8] */;\n  %267 = nn.conv2d(%266, meta[relay.Constant][28] /* ty=Tensor[(1024, 128, 1, 1), int8] */, strides=[2, 2], padding=[0, 0, 0, 0], channels=1024, kernel_size=[1, 1], out_dtype="int32") /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %268 = add(%267, 128 /* ty=int32 */) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %269 = right_shift(%268, 8 /* ty=int32 */) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %270 = clip(%269, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %271 = cast(%270, dtype="int8") /* ty=Tensor[(1, 1024, 7, 7), int8] */;\n  %272 = annotation.stop_fusion(%271) /* ty=Tensor[(1, 1024, 7, 7), int8] */;\n  %273 = cast(%272, dtype="int32") /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %274 = strided_slice(%265, begin=[0, 128, 0, 0], end=[1, 256, 14, 14], strides=[1, 1, 1, 1], axes=None) /* ty=Tensor[(1, 128, 14, 14), int8] */;\n  %275 = nn.conv2d(%274, meta[relay.Constant][29] /* ty=Tensor[(1024, 128, 1, 1), int8] */, strides=[2, 2], padding=[0, 0, 0, 0], channels=1024, kernel_size=[1, 1], out_dtype="int32") /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %276 = add(%275, 128 /* ty=int32 */) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %277 = right_shift(%276, 8 /* ty=int32 */) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %278 = clip(%277, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %279 = cast(%278, dtype="int8") /* ty=Tensor[(1, 1024, 7, 7), int8] */;\n  %280 = annotation.stop_fusion(%279) /* ty=Tensor[(1, 1024, 7, 7), int8] */;\n  %281 = cast(%280, dtype="int32") /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %282 = add(%273, %281) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %283 = cast(%282, dtype="int8") /* ty=Tensor[(1, 1024, 7, 7), int8] */;\n  %284 = annotation.stop_fusion(%283) /* ty=Tensor[(1, 1024, 7, 7), int8] */;\n  %285 = cast(%284, dtype="int32") /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %286 = add(%262, %285) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %287 = nn.relu(%286) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %288 = clip(%287, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %289 = cast(%288, dtype="int8") /* ty=Tensor[(1, 1024, 7, 7), int8] */;\n  %290 = annotation.stop_fusion(%289) /* ty=Tensor[(1, 1024, 7, 7), int8] */;\n  %291 = nn.conv2d(%290, meta[relay.Constant][30] /* ty=Tensor[(1024, 1024, 3, 3), int8] */, padding=[1, 1, 1, 1], channels=1024, kernel_size=[3, 3], out_dtype="int32") /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %292 = add(%291, meta[relay.Constant][31] /* ty=Tensor[(1024, 1, 1), int32] */) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %293 = add(%292, 1024 /* ty=int32 */) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %294 = right_shift(%293, 11 /* ty=int32 */) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %295 = clip(%294, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %296 = cast(%295, dtype="int8") /* ty=Tensor[(1, 1024, 7, 7), int8] */;\n  %297 = annotation.stop_fusion(%296) /* ty=Tensor[(1, 1024, 7, 7), int8] */;\n  %298 = cast(%297, dtype="int32") /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %299 = cast(%288, dtype="int8") /* ty=Tensor[(1, 1024, 7, 7), int8] */;\n  %300 = annotation.stop_fusion(%299) /* ty=Tensor[(1, 1024, 7, 7), int8] */;\n  %301 = cast(%300, dtype="int32") /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %302 = add(%298, %301) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %303 = nn.relu(%302) /* ty=Tensor[(1, 1024, 7, 7), int32] */;\n  %304 = cast(%303, dtype="int8") /* ty=Tensor[(1, 1024, 7, 7), int8] */;\n  %305 = annotation.stop_fusion(%304) /* ty=Tensor[(1, 1024, 7, 7), int8] */;\n  %306 = cast(%305, dtype="float32") /* ty=Tensor[(1, 1024, 7, 7), float32] */;\n  %307 = multiply(%306, 0.0625f /* ty=float32 */) /* ty=Tensor[(1, 1024, 7, 7), float32] */;\n  %308 = nn.adaptive_avg_pool2d(%307, output_size=[1, 1]) /* ty=Tensor[(1, 1024, 1, 1), float32] */;\n  %309 = reshape(%308, newshape=[-1, 1024]) /* ty=Tensor[(1, 1024), float32] */;\n  %310 = nn.dense(%309, meta[relay.Constant][32] /* ty=Tensor[(10, 1024), float32] */, units=10) /* ty=Tensor[(1, 10), float32] */;\n  add(%310, meta[relay.Constant][33] /* ty=Tensor[(10), float32] */) /* ty=Tensor[(1, 10), float32] */\n}\n\n/* For debugging purposes the metadata section has been omitted.\n * If you would like to see the full metadata section you can set the \n * option to `True` when invoking `astext`. \n */')
# Out:
# #[version = "0.0.5"]
# def @main(%input0: Tensor[(1, 3, 224, 224), float32]) -> Tensor[(1, 10), float32] {
#   %0 = nn.conv2d(%input0, meta[relay.Constant][0] /* ty=Tensor[(32, 3, 7, 7), float32] */, strides=[2, 2], padding=[3, 3, 3, 3], channels=32, kernel_size=[7, 7]) /* ty=Tensor[(1, 32, 112, 112), float32] */;
#   %1 = add(%0, meta[relay.Constant][1] /* ty=Tensor[(32, 1, 1), float32] */) /* ty=Tensor[(1, 32, 112, 112), float32] */;
#   %2 = nn.relu(%1) /* ty=Tensor[(1, 32, 112, 112), float32] */;
#   %3 = nn.max_pool2d(%2, pool_size=[2, 2], strides=[2, 2], padding=[0, 0, 0, 0]) /* ty=Tensor[(1, 32, 56, 56), float32] */;
#   %4 = annotation.stop_fusion(%3) /* ty=Tensor[(1, 32, 56, 56), float32] */;
#   %5 = strided_slice(%4, begin=[0, 0, 0, 0], end=[1, 8, 56, 56], strides=[1, 1, 1, 1], axes=None) /* ty=Tensor[(1, 8, 56, 56), float32] */;
#   %6 = multiply(%5, 16f /* ty=float32 */) /* ty=Tensor[(1, 8, 56, 56), float32] */;
# ...
